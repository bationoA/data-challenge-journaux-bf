# %%
import os
import re
print("Imported.")
# Out:
# Imported.

# %%
def clean_text(txt):
    import re
    # Replace special characters with spaces
    cleaned_text = re.sub(r'[•*■]', ' ', txt)
    
    # Remove unnecessary newlines and extra spaces
    cleaned_text = re.sub(r'\n+', ' ', cleaned_text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    
    # Correct spacing around punctuation marks
    cleaned_text = re.sub(r'\s([.,:;!?])', r'\1', cleaned_text)
    cleaned_text = re.sub(r'([.,:;!?])\s', r'\1 ', cleaned_text)
    
    return cleaned_text.strip()

# %%
def fix_formatting(text_):

    # text_ = process_text(text_)
    text_ = clean_text(text_)
    

    
    # Split the text_ into lines
    lines = text_.split("\n")
    # Initialize a list to hold the fixed lines
    fixed_lines = []
    # Iterate over each line
    for line in lines:
        # If the line is empty or contains only whitespace, skip it
        if not line.strip():
            continue
        # Remove leading and trailing whitespace from the line
        line = line.strip()
        # Append the fixed line to the list
        fixed_lines.append(line)
    # Join the fixed lines into a single string with newline characters
    fixed_text = "\n".join(fixed_lines)
    fixed_text = fixed_text.replace("n°", "numero").replace("N°", "numero")
    return fixed_text

# %%
def remove_special_characters(txt, keep:list=None):
    # Define the pattern to match special characters
    # pattern = r'[^\w\s]'
    special_chars = "!@#$%^&*()-_=+[]{};:'\",.<>/?\|`~"
    
    if keep is not None:
        for sch in keep:
            special_chars = special_chars.replace(f"{sch}", "")

    for sp in list(special_chars):
        txt = txt.replace(sp, "") 
    return txt

# %%
# Example usage:
text_special_char = "This is a text with special characters: !@#$%^&*()-_=+[]{};:'\",.<>/?\|`~"
remove_special_characters(text_special_char, keep=["(", ")", "^"])
# Out:
# 'This is a text with special characters ^()'

# %%
def extract_declaration_sections(txt, keyword, first=True):
    txt = txt.lower().replace("é", "e")
    # Compile a regular expression pattern to match sections based on the keyword
    recepisse = "cepisse"
    recepisse = "\s?".join(recepisse)
    recepisse = "r?e?" + recepisse
    denomination = "denomination"
    denomination = "\s?".join(denomination)
    pattern = re.compile(rf"{keyword}.*?president.*?(?=\br?{recepisse}|{denomination}\b|$)", re.DOTALL)
    # pattern = re.compile(rf"\b{keyword}\b.*?(?=\b{keyword}\b|$)", re.DOTALL)
    # Find all matches of the pattern in the text
    sections = pattern.findall(txt)
    if len(sections):
        sections = [sc.strip() for sc in sections]

    return sections if not first else sections[0]

# %%
def extract_declaration_numbers_and_dates(txt):
    txt = txt.lower().replace("é", "e")
    declaration = "declaration"
    declaration = "\s?".join(declaration)
    # declaration += "?\s?d?\s?\\?’?"
    declaration += "\s?d?\s?'?"
    declaration += "\s?".join("association")
    # Define the pattern to match the declaration numbers
    pattern = re.compile(r"\s?.*?" + declaration + "\s?(.*?du.*?\d{4})")
    # Find all matches of the pattern in the text
    declaration_numbers = pattern.findall(txt)
    # Remove 'n°'
    declaration_numbers_dates = [dc.removeprefix("n°").removeprefix(" n").removeprefix('n"').split("du") for dc in declaration_numbers]
    results = []
    for dn_dt in declaration_numbers_dates:
        try:
            new_dn_dt = dn_dt[0].strip(), dn_dt[1].strip() if len(dn_dt) == 2 else dn_dt[0].strip()
            results.append(new_dn_dt)
        except:
            pass

    return results

# %%
def get_association_name(txt: str) -> str:
    txt = txt.replace("é", "e").replace("è", "e").lower()

    txt = remove_special_characters(txt=txt, keep=["(", ")"])
    
    # Pattern to find the denomination
    pattern = re.compile(r"(?i)(?u)denomination:?\s*(.*?)(?:\s*en abrege|abrege|siege|\()", re.DOTALL)
    
    matches = re.findall(pattern, txt)
    return matches[0].strip().upper() if len(matches) else ""

# %%
def get_abbrevation_1(txt: str, denomination: str) -> str:
    """
    Pattern to find the abbreviation based on the denomination: denomination followed by abbreviation like '(A.S.K.)'
    """
    txt = txt.lower().replace("é", "e").replace('"', '').replace("'", "")
    
    denomination = denomination.lower()
    
    pattern = re.compile(rf"{denomination}\s*\((.*?)\)\s")
    
    # Find abbreviation in the text
    matches = re.findall(pattern, txt.lower())
    abbreviation = matches[0].strip().upper() if len(matches) else ""
    abbreviation = abbreviation.removesuffix(".")

    return abbreviation

def get_abbrevation_2(txt: str, denomination: str) -> str:
    txt = txt.replace("é", "e").lower().replace('"', '').replace("'", "")
    
    denomination = denomination.lower()
    
    # Pattern to find the abbreviation based on the denomination: denomination followed by abbreviation like '(A.S.K.)'
    pattern = re.compile(rf"{denomination}\s*en abrege\s*(\(?.*?\)?)\s")
    
    # Find abbreviation in the text
    matches = re.findall(pattern, txt.lower())
    abbreviation = matches[0].strip().upper() if len(matches) else ""
    abbreviation = abbreviation.removesuffix(".")

    return abbreviation

# %%
def get_association_abbreviation(txt: str, denomination: str = None) -> str:
    # txt = txt.lower()
    if denomination is None:
        denomination = get_association_name(txt)

    txt = remove_special_characters(txt=txt, keep=["(", ")"])

    denomination = re.escape(denomination)

    # Try pattern: denomination followed by abbreviation like '(A.S.K.)'
    abbreviation = get_abbrevation_1(txt=txt, denomination=denomination)

    # Return abbreviation if found
    if abbreviation != "":
        return abbreviation

    # If abbreviation not foound
    # Try pattern: denomination followed by abbreviation like 'A.S.K.'
    abbreviation = get_abbrevation_2(txt=txt, denomination=denomination)    

    return abbreviation

# %%
def get_siege(txt: str) -> str:
    
    txt = txt.lower().replace("é", "e").replace("è", "e").replace('"', '').replace("'", "")
    txt = remove_special_characters(txt=txt)

    # print(txt)
    
    # denomination = denomination.lower()

    siege = "\s?".join("siege")
    objectif = "\s?".join("objectif")
    
    pattern = re.compile(rf"{siege}\s*?:?(.*?)(?:\s*{objectif}|,|\.)")

    # print(f"\n{pattern}")
    
    # Find abbreviation in the text
    matches = re.findall(pattern, txt)
    siege = matches[0].strip().upper() if len(matches) else ""
    siege = siege.removesuffix(".")

    return siege

# %%
def get_objectifs(txt: str) -> str:
    
    txt = txt.lower().replace("é", "e").replace("è", "e").replace('"', '').replace("'", "")
    # txt = remove_special_characters(txt=txt)

    # print(txt)
    
    # denomination = denomination.lower()

    objectif = "\s?".join("objectif")
    
    # pattern = re.compile(rf"{objectif}s?(.*?)(?:\s*la composition|les noms|noms|prenoms|noms,prenoms|nom,prenom|nom et prenom|le bureau|bureau)")
    pattern = re.compile(rf"{objectif}s?(.*?)(?:\s*la composition|les noms|prenoms|noms, prenoms|nom, prenom|nom et prenom|noms|le bureau|bureau)")

    # print(f"\n{pattern}")
    
    # Find abbreviation in the text
    matches = re.findall(pattern, txt)
    objectifs = matches[0].strip().capitalize() if len(matches) else ""

    return objectifs

# %%
def extract_association_details(file: str, dec_num_date: str) -> dict:
    association = dict()

    num, dt = dec_num_date
    section = extract_declaration_sections(keyword=num, txt=file, first=True)

    # Association
    association['number'] = num
    association['date'] = dt
    association['denomination'] = get_association_name(txt=section)
    association['abbreviation'] = get_association_abbreviation(txt=section, denomination=association['denomination'])
    association['siege'] = get_siege(txt=section)
    association['objective'] = get_objectifs(txt=section)

    return association

# %% [markdown]
# ## Testing on files

# %%
def read_file(file_path: str) -> str | None:
    try:
        with open(file_path, "r") as f:
            return f.read()
    except BaseException as e:
        print(f"Error: {e.__str__()}")
        return None

# %%
DOWNLOADED_FILES_FOLDER = os.path.join("data", "journaux")
all_files_names = os.listdir(DOWNLOADED_FILES_FOLDER)
print(len(all_files_names))
print(all_files_names[0:5])
# Out:
# 451
# ['file_llflg.87648643_20150910_01.txt', 'file_llflg.87648643_20160418_01.txt', 'file_llflg.87648643_20080313_01.txt', 'file_llflg.87648643_20080228_01.txt', 'file_llflg.87648643_20210211_01.txt']

# %%
files_paths = [os.path.join(DOWNLOADED_FILES_FOLDER, file_name) for file_name in all_files_names]
print(len(files_paths))
print(files_paths[0:2])
# Out:
# 451
# ['data/journaux/file_llflg.87648643_20150910_01.txt', 'data/journaux/file_llflg.87648643_20160418_01.txt']

# %%
for file_path in files_paths[0:1]:
    file = read_file(file_path)
    if "declaration" not in file.lower().replace("é", "e"):
        print(f"Not in: {file_path}")

# %%
first_file_path = files_paths[0]
print(f"path: {first_file_path}")
first_file_content = read_file(first_file_path)
print(f"Read.")
# Out:
# path: data/journaux/file_llflg.87648643_20150910_01.txt
# Read.

# %%
first_file_content = clean_text(txt=first_file_content)
print(len(first_file_content))
first_file_content[100000:-30000]
# Out:
# 140687
# 'udes et de la recherche SOMA Assonsi, Tél. 72 05 05 78 78 74 29 25 Récépissé de déclaration d\'association n° 2015- 431/MATD/SG/DGLPAP/DOASOC du 11 août 2015. Le Ministre de l\'administration territoriale et de la décentralisation, donne aux personnes ci-après désignées, récépissé de déclaration d\'existence pour l\'association régie par la loi n° 10/92/ADP du 15 décembre 1992, portant liberté d\'association. Dénomination de l\'Association Réseau International pour la Promotion de la Pédagogie du Texte, en abrégé RIP/PDT Siège Ouagadougou, Province du Kadiogo Objectifs Le Réseau International pour la Promotion de la Pédagogie du Texte a pour objectifs créer une communauté éducative autour de l\'approche Pdt assurer des échanges et des partages d\'informations autour des expériences relatives à la mise en œuvre de la Pdt approfondir la recherche sur la Pdt pour son enrichissement renforcer les capacités compétences des membres du Réseau contribuer à la promotion pédagogique et politique de l\'approche Pdt à travers le monde participer à la mise en œuvre de programmes d\'éducation. La composition de l\'organe dirigeant du Réseau International pour la Promotion de la Pédagogie du Texte est la suivante Président HIEN D. Lambert, Tél. 70 23 13 32 Secrétaire
dec_num_dates_list = extract_declaration_numbers_and_dates(txt=temp)
len(dec_num_dates_list)
# Out:
# 1

# %%
dec_num_dates_list
# Out:
# [('2015- 426/matdisgidglpap/doasoc', '06 août 2015')]

# %%
temp.lower().replace("é", "e")
# Out:
# 'ecepisse de declaration d\'association n" 2015- 426/matdisgidglpap/doasoc du 06 août 2015. le ministre de l\'administration territoriale et de la decentralisation, donne aux personnes ci-après designees, recepisse de declaration d\'existence pour l\'association regie par la loi n° 10/92/adp du 15 decembre 1992, portant liberte d\'association. denomination association des consommateurs des produits financiers, en abrege acpf siège ouagadougou, province du kadiogo objectifs l\'association des consommateurs des produits financiers a pour objectifs informer et former les'

# %%
dec_num_dates_list = extract_declaration_numbers_and_dates(txt=first_file_content)
print(len(dec_num_dates_list))
dec_num_dates_list
# Out:
# 43
# [('2013- 172/mats/rhbs/pknd/hc', '13 mai 2013'),
#  ('2015- 090/matd/rhbs/gbd/sg/be', '29 juillet 2015'),
#  ('2015- 437/matd/sg/dglpap/doasoc', '11 août 2015'),
#  ('2015- 460/matd/sgidglpapidoasoc', '20 août 2015'),
#  ('2015- 181/matd/rcen/pkad/hc/sg/dase', '24 août 2015'),
#  ('2015- 164/matd/rcen/pkad/hc/sg/dase', '31 juillet 2015'),
#  ('2015- 022/matds/rnrd/gvr-ohg/sg', '15 juin 2015'),
#  ('2015- 464/matd/sg/dglpap/doasoc', '20 août 2015'),
#  ('2015- 411/matd/sg/dglpap/doasoc', '31 juillet 2015'),
#  ('2015- 028/matd/rnrd/gvr-ohg/sg', '19 août 2015'),
#  ('2015- 429/matdisgidglpapidoasoc', '06 août 2015'),
#  ('2015- 029/matd/rnrd/gvr-ohg/sg', '21 août 2015'),
#  ('2015- 421/matd/sg/dglpap/doasoc', '03 août 2015'),
#  ('2015 409/matd/sgidglpap/doasoc', '31 juillet 2015'),
#  ('2015- 06/matds/rsuo/pnbl/hc-bat', '22 mai 2015'),
#  ('2015- 023/matds/rcsd/pnhr/hc', '03 juillet 2015'),
#  ('2015- 034/matd/rcnr/psnm/hc', '27 juillet 2015'),
#  ('2015- 180/matd/rcen/pkad/hc/sg/dase', '20 août 2015'),
#  ('2015- 368/matdsisg/dglpap/doasoc', '09 juillet 2015'),
#  ('2015- 394/matdsisg/dglpap/doasoc', '21 juillet 2015'),
#  ('2015- 473/matd/sg/dglpap/doasoc', '25 août 2015'),
#  ('2015- 418/matd/sg/dglpap/doasoc', '31 juillet 2015'),
#  ('2015- 448/matd/sg/dglpap/doasoc', '11 août 2015'),
#  ('2015- 478/matd/sg/dglpap/doasoc', '26 août 2015'),
#  ('2015- 413/matd/sg/dglpap/doasoc', '31 juillet 2015'),
#  ('2015- 452/matd/sgidglpap/doasoc', '11 août 2015'),
#  ('2015- 431/matd/sg/dglpap/doasoc', '11 août 2015'),
#  ('2015- 463/matd/sg/dglpap/doasoc', '20 août 2015'),
#  ('2015- 510/matd/sg/dglpap/doasoc', '31 août 2015'),
#  ('2015- 474imatd/sg/dglpap/doasoc', '26 août 2015'),
#  ('2015- 426/matdisgidglpap/doasoc', '06 août 2015'),
#  ('2015- 185/matd/rcen/pkad/hc/sg/dase', '26 août 2015'),
#  ('2015- 162/matd/rcen/pkad/hc/sg/dase', '31 juillet 2015'),
#  ('2015- 218/matds/rhbs/phue/hcbdls/sg/dag', '08 juillet 2015'),
#  ('2015- 255/matds/rhbs/phue/hcbdls/sg/dag', '29 juillet 2015'),
#  ('2015- 034/matds/rnrd/pytg/hc-ohg/sg', '24 juillet 2015'),
#  ('2015 057/matds/rcos/pblk/hc-kdg/sg', '19 mars 2015'),
#  ('2015- 085/matds/rcas/pcmo/hc', '14 juillet 2015'),
#  ('2015- 018/matd/rbmh/pbl/hc-brm', '19 août 2015'),
#  ('2015- 025/matd/rbmh/pmhn/hc-ddg/sg', '12 août 2015'),
#  ('2015- 004imatd/rcnr/pnmt/hcisg', '18 août 2015'),
#  ('2015- 018/matds/rpcl/pkwg/hc/sg', '18 août 2015'),
#  ('2015- 024/matd/rest/pgng/hc', '24 août 2015')]

# %%
tmp = "2008- 086/ma td/sg/dglpa p/doasoc 19 fevrier 2008. le ministre de l'administration territoriale et de la decentralisa- tion, donne aux personnes ci-après designees recepisse de declaration d'existence pour l'association regie par la loi n° 10/92/adp 15 decembre 1992"

extract_declaration_numbers_and_dates(txt=tmp)
# Out:
# []

# %%
from tqdm import tqdm

# %%
associations = []
for num_date in tqdm(dec_num_dates_list):
    num = num_date[0]
    current_section = extract_declaration_sections(keyword=num, txt=first_file_content, first=True)

    current_association = extract_association_details(file=current_section, dec_num_date=num_date)
    rsult = {}
    for key in current_association.keys():
        rsult[f"is_{key}_valid"] = current_association[key] != ""

    rsult['section'] = current_section
    rsult['association'] = current_association
    
    associations.append(rsult)

print("Done.")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 493.77it/s]
# Done.

# %%
associations
# Out:
# [{'is_number_valid': True,
#   'is_date_valid': True,
#   'is_denomination_valid': True,
#   'is_abbreviation_valid': False,
#   'is_siege_valid': True,
#   'is_objective_valid': True,
#   'section': "2013- 172/mats/rhbs/pknd/hc du 13 mai 2013. le haut- commissaire de la province du kenedougou, donne aux personnes ci-après designees, recepisse de declaration d'existence pour l'association regie par la loi n° 10/92/adp du 15 decembre 1992, portant liberte d'association. denomination association n'binidjo de n'dosso siège n'dosso, departement de kayan objectifs l'association n'binidjo de n'dosso se fixe pour objectifs de promouvoir la culture de la paix entre burkinabe contribuer à la sauvegarde de la dignite humaine promouvoir l'auto-emploi des jeunes dans les domaines de l'elevage et de l'agriculture contribuer à la preservation de l'environnement par des seances de sensibilisation contribuer à l'elevation du niveau de sante des jeunes par des sensibilisations contribuer à l'education civique des membres sur les valeurs de la republique participer à l'exportation de nos valeurs culturelles mettre l'accent sur l'education des jeunes filles mettre l'accent sur l'auto-emploi des femmes en milieu rural la composition de l'organe dirigeant de l'association lumière de orodara est la suivante president dao songoro siaka, tel. 76 72 26 24 vice-president bayo lamine, te. 76 37 21 09 secretaire general ssessouma alassane, tel. 76 03 28 06 secretaire adjoint dao kassoum, tel. 75 14 05 23 tresorier general dao lassina, tel. 76 69 03 10 tresorière adjointe sanou bintou responsable à l'information dao nangoro responsable adjoint à l'information bayo gnazegue responsable à la mobilisation feminine guetta mariam responsable adjointe à la mobilisation feminine konate fatima commissaires aux comptes dao yacouba dao lamoussa",
#   'association': {'number': '2013- 172/mats/rhbs/pknd/hc',
#    'date': '13 mai 2013',
#    'siege': 'BOULSA SECTEUR N° 3 TOAGA DEPARTEMENT DE BOULSA PROVINCE DU NAMENTENGA',
#    'objective': 'Lassociation des femmes beoog-neere de toaga a pour objectifs de ameliorer les conditions sanitaires des populations par la promotion de la sante maternelle et infantile œuvrer à ameliorer les conditions dapprentissage et de formation des femmes promouvoir des initiatives economiques des femmes (developper des activites generatrices de revenu et des microprojets) participer à tout developpement de la localite promouvoir la restauration et la protection de lenvironnement developper les relations du partenariat avec dautres organisation et institution sur les mêmes buts et objectifs promouvoir lautonomie financiere des membres ameliorer le statut social de la femme et de la jeune fille contribuer à lelevation du taux de scolarisation et lalphabetisation des populations principalement les jeunes filles et les femmes par la promotion de leducation.'}},
#  {'is_number_valid': True,
#   'is_date_valid': True,
#   'is_denomination_valid': True,
#   'is_abbreviation_valid': True,
#   'is_siege_valid': True,
#   'is_objective_valid': True,
#   'section': "2015- 018/matds/rpcl/pkwg/hc/sg du 18 août 2015. le haut-commissaire la province du kourweogo, donne aux personnes ci-après designees, recepisse de declaration d'existence pour l'association regie par la loi n° 10/92/adp du 15 decembre 1992, portant liberte d'association. denomination association des jeunes musulmans de bousse, en abrege a.j.m.b siège bousse, province du kourweogo objectifs l'association des jeunes musulmans de bousse poursuit les objectifs suivants permettre une cohesion sociale entre les jeunes musulmans lutter contre les fleaux tels que la drogue, la consommation d'alcool, de tout genre par certains jeunes musulmans travailler à eradiquer ou eliminer les divergences entre les differentes denominations musulmanes par l'enseignement du coran et de la sunna du prophète (psl) cultiver la paix entre les musulmans et surtout faire comprendre que l'islam n'aime pas la violence qu'elle minime ou majeure inciter les jeunes musulmans à la rechercher d'emploi afin de pouvoir creer et subvenir aux besoins de leurs familles. la composition de l'organe dirigeant de l'association des jeunes musulmans de bousse est la suivante president ouedraogo boureima, tel. 78 72 90 24 vice-president ouedraogo inoussa, tel. 79 68 29 25 secretaire general ouedraogo rasmane, tel. 70 52 01 31 secretaire adjoint tapsoba zakaria, tel. 68 24 43 76 tresorier general zore abdoulaye, tel. 76 25 53 49 tresorier adjoint kinda salif, tel. 78 17 54 28 secretaire à l'information ouedraogo souleymane, tel. 78 61 45 29 secretaire adjoint à l'information ilboudo sayouba, tel. 78 21 46 67",
#   'association': {'number': '2015- 018/matds/rpcl/pkwg/hc/sg',
#    'date': '18 août 2015',
#    'denomination': 'ASSOCIATION DES JEUNES MUSULMANS DE BOUSSE',
#    'abbreviation': 'AJMB',
#    'siege': 'BOUSSE PROVINCE DU KOURWEOGO',
#    'objective': 'Lassociation des jeunes musulmans de bousse poursuit les objectifs suivants permettre une cohesion sociale entre les jeunes musulmans lutter contre les fleaux tels que la drogue, la consommation dalcool, de tout genre par certains jeunes musulmans travailler à eradiquer ou eliminer les divergences entre les differentes denominations musulmanes par lenseignement du coran et de la sunna du prophete (psl) cultiver la paix entre les musulmans et surtout faire comprendre que lislam naime pas la violence quelle minime ou majeure inciter les jeunes musulmans à la rechercher demploi afin de pouvoir creer et subvenir aux besoins de leurs familles.'}},
#  {'is_number_valid': True,
#   'is_date_valid': True,
#   'is_denomination_valid': True,
#   'is_abbreviation_valid': True,
#   'is_siege_valid': True,
#   'is_objective_valid': True,
#   'section': "2015- 024/matd/rest/pgng/hc du 24 août 2015. le haut- commissaire de la province de la gnagna, donne aux personnes ci-après designees recepisse de declaration d'existence pour l'association regie par la loi n° 10/92/adp du 15 decembre 1992, portant liberte d'association. denomination
#    'siege': 'BOGANDE DEPARTEMENT DUDIT PROVINCE DE LA GNAGNA',
#    'objective': 'Lassociation feminine fandima de la gnagna (a.f.f.g) poursuit les objectifs suivants renforcer les capacites des membres à travers des formations specifiques construire un centre multifonctionnel pour la femme promouvoir lhygiene, la sante maternelle et infantile promouvoir les activites dans le domaine de lenvironnement et les droits de la femme promouvoir la connaissance reciproque des autres acteurs œuvrant dans ce sens elaborer des projets et programmes de developpement pour ameliorer les conditions de vie de la femme et de la jeune fille appuyer les efforts des autorites administratives, et autres acteurs œuvrer dans la recherche des moyens financiers, materiels et humains necessaires à la realisation des projets soutenir les associations similaires dans la realisation de leurs objectifs.'}}]

# %%
len(associations)
# Out:
# 43

# %%
for assoc in tqdm(associations):
    if not assoc["is_number_valid"] or not assoc["is_date_valid"] or not assoc["is_denomination_valid"] or not assoc["is_siege_valid"] or not assoc["is_objective_valid"]:
        print("\n\n---> NEW")
        print(f"\n{assoc['association']}")
        print(f"\n{assoc['section']}")
print("Done.")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 543238.17it/s]
# Done.

# %% [markdown]
# ### Get Members

# %%
positions = ['Secrétaire chargée des relations extérieures',
 'Responsable aux affaires sociales et économiques adjoint',
 'Responsable aux activités génératrices',
 "Secrétaire adjointe à l'organisation et à la communication",
 'Commissaires aux comptes',
 'Trésorière adjointe',
 'Secrétaire adjoint aux affaires culturelles',
 'Conseillers',
 'Secrétaire adjoint',
 'Responsable aux activités socio-culturelles',
 "Secrétaire adjoint à l'organisation",
 "Secrétaire chargé à l'information adjoint",
 "Responsable adjoint à l'information",
 "Secrétaire à l'organisation",
 'Secrétaire général',
 'Chargée adjointe de la question féminine',
 'Vice-président',
 "Secrétaire chargé à l'information",
 'Conseiller général',
 "Secrétaire adjoint à l'animation",
 'Représentante des femmes',
 'Responsable aux activités génératrices adjoint',
 "Secrétaire à l'organisation et à la communication",
 'Président',
 "Secrétaire chargé à l'organisation",
 "Secrétaire à l'animation",
 "Secrétaire adjoint à l'information",
 'Responsable à la mobilisation féminine',
 'Responsable adjointe à la mobilisation féminine',
 'Secrétaire aux affaires culturelles',
 'Responsable aux affaires sociales et économiques',
 "Responsable à l'information",
 'Chargé de la question féminine',
 'Trésorier général',
 'Secrétaire adjointe chargée des relations extérieures',
 "Secrétaire à l'information",
 'Trésorière']

# %%
def get_members(section: str, positions, objectifs: str=None):   
    members = dict()

    section += "."  # Add a full stop at the end of the section. It will be important when extracting the last member in the section


    section = section.replace("é", "e").replace("è", "e").replace("à", "a").lower()
    # print(section)
    print("\n")
    
    copy_positions = positions.copy()
    positions = [pos.replace("é", "e").replace("è", "e").replace("à", "a").lower() for pos in copy_positions]

    for position in positions:
        curr_position = position.replace("é", "e").replace("è", "e").replace("à", "a").lower()

        other_posistions = [pos for pos in positions if pos != curr_position]

        other_posistions_base = [pos.split(" ")[0] for pos in other_posistions]
        other_posistions_base = set(other_posistions_base)  # Remove duplicates

        stop_at = "|".join(other_posistions_base)
        # stop_at = "vice-president"
    
        # pattern = re.compile(rf"{curr_position}\s*?:?(.*?)(?:\s*,|\.|{stop_at})")
        pattern = re.compile(rf"{curr_position}\s*?:?(.*?)(?:\s*{stop_at})")
        # print(f"\n{pattern}")
        
        # Find abbreviation in the text
        matches = re.findall(pattern, section)
        person = matches[0].strip().upper() if len(matches) else ""
        person = person.removesuffix(".")

        members[curr_position] = person


    return [{key.upper():members[key]} for key in members.keys() if members[key] != ""]

tmp_section = "2013- 172/mats/rhbs/pknd/hc du 13 mai 2013. le haut- commissaire de la province du kenedougou, donne aux personnes ci-après designees, recepisse de declaration d'existence pour l'association regie par la loi n° 10/92/adp du 15 decembre 1992, portant liberte d'association. denomination association n'binidjo de n'dosso siège n'dosso, departement de kayan objectifs l'association n'binidjo de n'dosso se fixe pour objectifs de promouvoir la culture de la paix entre burkinabe contribuer à la sauvegarde de la dignite humaine promouvoir l'auto-emploi des jeunes dans les domaines de l'elevage et de l'agriculture contribuer à la preservation de l'environnement par des seances de sensibilisation contribuer à l'elevation du niveau de sante des jeunes par des sensibilisations contribuer à l'education civique des membres sur les valeurs de la republique participer à l'exportation de nos valeurs culturelles mettre l'accent sur l'education des jeunes filles mettre l'accent sur l'auto-emploi des femmes en milieu rural la composition de l'organe dirigeant de l'association lumière de orodara est la suivante president dao songoro siaka, tel. 76 72 26 24 vice-president bayo lamine, te. 76 37 21 09 secretaire general ssessouma alassane, tel. 76 03 28 06 secretaire adjoint dao kassoum, tel. 75 14 05 23 tresorier general dao lassina, tel. 76 69 03 10 tresorière adjointe sanou bintou responsable à l'information dao nangoro responsable adjoint à l'information bayo gnazegue responsable à la mobilisation feminine guetta mariam responsable adjointe à la mobilisation feminine konate fatima commissaires aux comptes dao yacouba dao lamoussa"
get_members(section=tmp_section, positions=positions)
# Out:
# [{'TRESORIERE ADJOINTE': 'SANOU BINTOU'},
#  {'SECRETAIRE ADJOINT': 'DAO KASSOUM, TEL. 75 14 05 23'},
#  {"RESPONSABLE ADJOINT A L'INFORMATION": 'BAYO GNAZEGUE'},
#  {'SECRETAIRE GENERAL': 'SSESSOUMA ALASSANE, TEL. 76 03 28 06'},
#  {'VICE-PRESIDENT': 'BAYO LAMINE, TE. 76 37 21 09'},
#  {'PRESIDENT': 'DAO SONGORO SIAKA, TEL. 76 72 26 24'},
#  {'RESPONSABLE A LA MOBILISATION FEMININE': 'GUETTA MARIAM'},
#  {'RESPONSABLE ADJOINTE A LA MOBILISATION FEMININE': 'KONATE FATIMA'},
#  {"RESPONSABLE A L'INFORMATION": 'DAO NANGORO'},
#  {'TRESORIER GENERAL': 'DAO LASSINA, TEL. 76 69 03 10'},
#  {'TRESORIERE': 'ADJOINTE SANOU BINTOU'}]

# %%
members = []
for num_date in tqdm(dec_num_dates_list):
    num = num_date[0]
    current_section = extract_declaration_sections(keyword=num, txt=first_file_content, first=True)

    current_members = get_members(section=current_section, positions=positions)
    rsult = {
        "Association number": num_date,
        "Members": current_members
    }
    
    members.append(rsult)

print("Done.")
print(f"Members n: {len(members)}")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 643.66it/s]
# Done.
# Members n: 43

# %%
members
# Out:
# [{'Association number': ('2013- 172/mats/rhbs/pknd/hc', '13 mai 2013'),
#   'Members': [{'TRESORIERE ADJOINTE': 'SANOU BINTOU'},
#    {'SECRETAIRE ADJOINT': 'DAO KASSOUM, TEL. 75 14 05 23'},
#    {"RESPONSABLE ADJOINT A L'INFORMATION": 'BAYO GNAZEGUE'},
#    {'SECRETAIRE GENERAL': 'SSESSOUMA ALASSANE, TEL. 76 03 28 06'},
#    {'VICE-PRESIDENT': 'BAYO LAMINE, TE. 76 37 21 09'},
#    {'PRESIDENT': 'DAO SONGORO SIAKA, TEL. 76 72 26 24'},
#    {'RESPONSABLE A LA MOBILISATION FEMININE': 'GUETTA MARIAM'},
#    {'RESPONSABLE ADJOINTE A LA MOBILISATION FEMININE': 'KONATE FATIMA'},
#    {"RESPONSABLE A L'INFORMATION": 'DAO NANGORO'},
#    {'TRESORIER GENERAL': 'DAO LASSINA, TEL. 76 69 03 10'},
#    {'TRESORIERE': 'ADJOINTE SANOU BINTOU'}]},
#  {'Association number': ('2015- 090/matd/rhbs/gbd/sg/be', '29 juillet 2015'),
#   'Members': [{'RESPONSABLE AUX AFFAIRES SOCIALES ET ECONOMIQUES ADJOINT': 'DIALLO YACOUBA, TEL. 76 46 14 31'},
#    {'RESPONSABLE AUX ACTIVITES GENERATRICES': 'OUEDRAOGO SOULEYMAE, TEL. 76 36 98 55'},
#    {'COMMISSAIRES AUX COMPTES': 'OUATTARA ADAMA, TEL. 70 74 37 28 SOULAMA ABDEL AZIZ, TEL. 78 57 59 62'},
#    {"SECRETAIRE CHARGE A L'INFORMATION ADJOINT": 'TRAORE BRAMA, TEL. 76 32 03 57'},
#    {'SECRETAIRE GENERAL': 'DRABO ABDOULAYE, TEL. 70 22 09 98'},
#    {'VICE-PRESIDENT': 'SOURACLIN MAMADOU, TEL. 78 14 97 22'},
#    {"SECRETAIRE CHARGE A L'INFORMATION": 'OUATARA M. DIAKALIA, TEL. 76 88 36 33'},
#    {'RESPONSABLE AUX ACTIVITES GENERATRICES ADJOINT': 'OUATTAR IBRAHIM, TEL. 78 89 97 94'},
#    {'PRESIDENT': 'SEREME SOUALI,TEL. 76 15 08 29'},
#    {'RESPONSABLE AUX AFFAIRES SOCIALES ET ECONOMIQUES': 'COULIBALY DRISSA, TEL. 70 02 31 85'},
#    {'TRESORIER GENERAL': 'ADJOINT OUATTARA ISSOUMAHILA, TEL. 72 17 18 57'},
#    {'TRESORIERE': 'GENERALE OUATTARA MAIMOUNA, TEL. 76 58 12 07'}]},
#  {'Association number': ('2015- 437/matd/sg/dglpap/doasoc', '11 août 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'SAWADOGO FATIMATA, TEL. 76 58 46 47'},
#    {'SECRETAIRE ADJOINT': "E A L'INFORMATION ET A LA COMMUNICATION YANOGO MARIAM, TEL. 68 68 64 73"},
#    {"SECRETAIRE A L'ORGANISATION": 'ROUAMBA NINDA ODILE, TEL. 76 37 18 17'},
#    {'SECRETAIRE GENERAL': 'E BEREWIDOUGOU MARINA, TEL. 78 96 90 39'},
#    {'VICE-PRESIDENT': 'TIENDREBEOGO ADAMA,TEL.79 18 41 40/ 76 86 15 47'},
#    {'PRESIDENT': 'DOAMBA ADAMA,TEL. 78 60 35 56'},
#    {"SECRETAIRE A L'INFORMATION": 'ET A LA COMMUNICATION WANGRAWA NATEWENDE ADAMA, TEL. 75 42 38 27'},
#    {'TRESORIERE': 'ZOUNGRANA SIBDOU, TEL. 79 63 59 62'}]},
#  {'Association number': ('2015- 460/matd/sgidglpapidoasoc', '20 août 2015'),
#   'Members': [{'SECRETAIRE GENERAL': 'E: KOUDOUMA DJEMILATOU,TEL. 78 19 26 11'},
#    {'PRESIDENT': 'MAIGA IDRISSA SAMBO, TEL. 70 40 85 04'},
#    {'TRESORIER GENERAL': 'MAIGA ISSA IDRISSA, TEL. 71 99 28 59 DIRECTEUR ARTISTIQUE MAIGA DJENEBA ISSA, TEL. 70 94 54 76'}]},
#  {'Association number': ('2015- 181/matd/rcen/pkad/hc/sg/dase',
#    '24 août 2015'),
#   'Members': [{'SECRETAIRE CHARGEE DES RELATIONS EXTERIEURES': 'SAWADOGO BINTOU, TEL. 60 48 03 51'},
#    {'SECRETAIRE ADJOINT': "E A L'INFORMATION KOMBEOGO SALAMATA, TEL. 79 55 75 50"},
#    {"SECRETAIRE A L'ORGANISATION": 'KANAZOE SALAMATA, TEL. 77 68 46 88'},
#    {'SECRETAIRE GENERAL': 'E KORBEOGO RAKIATA.TEL. 71 84 66 16 PAGE 16 630 JOURNAL OFFICIEL DU BURKINA FASO N° 37 10 SEPTEMBRE 2015'},
#    {'VICE-PRESIDENT': 'E SAWADOGO MARIETOU.TEL. 77 24 23 76'},
#    {'PRESIDENT': 'E SANFO RASMATA, TEL. 72 40 41 04'},
#    {"SECRETAIRE A L'INFORMATION": 'DAKISSAGA ASSETA, TEL. 64 75 63 68'},
#    {'TRESORIERE': 'GENERALE: OUEDRAOGO PASCALINE,TEL. 70 85 20 21'}]},
#  {'Association number': ('2015- 164/matd/rcen/pkad/hc/sg/dase',
#    '31 juillet 2015'),
#   'Members': [{'SECRETAIRE ADJOINT AUX AFFAIRES CULTURELLES': 'ET SPORTIVES OUEDRAOGO JEAN BARON, TEL. 77 31 28 98'},
#    {'SECRETAIRE ADJOINT': "A L'INFORMATION ZONGO LAZENI, TEL. 78 40 61 33"},
#    {"SECRETAIRE ADJOINT A L'ORGANISATION": 'BASSOLE BOUMA ADAMS, TEL. 78 98 08 55'},
#    {"SECRETAIRE A L'ORGANISATION": 'TRAORE KALIFA, TEL. 78 28 44 67'},
#    {'SECRETAIRE GENERAL': 'SAKANDE AMIDOU, TEL. 68 50 94 66'},
#    {'VICE-PRESIDENT': 'SAWADOGO ADAMA, TEL. 70 34 57 03'},
#    {'PRESIDENT': 'SAKANDE ADAMA, TEL. 78 31 20 96'},
#    {"SECRETAIRE ADJOINT A L'INFORMATION": 'ZONGO LAZENI, TEL. 78 40 61 33'},
#    {'SECRETAIRE AUX AFFAIRES CULTURELLES': 'ET SPORTIVES SOME GEORGES, TEL. 79 11 93 97'},
#    {'TRESORIER GENERAL': 'TAPSOBA VALENTIN, TEL. 78 70 95 07 TRESORIER GENERAL ADJOINT KAFANDO OMAR, TEL. 79 17 48 47'},
#    {"SECRETAIRE A L'INFORMATION": 'NABOLE ADAMA, TEL. 78 99 61 19'}]},
#  {'Association number': ('2015- 022/matds/rnrd/gvr-ohg/sg', '15 juin 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': 'AUX ACTIVITES SOCIO-CULTURELLES GANAME SOULEYMANE, TEL. 70 79 22 59'},
#    {'SECRETAIRE GENERAL': 'OUEDRAOGO ADAMA, TEL. 78 11 64 76'},
#    {'VICE-PRESIDENT': 'BELEM ZAKARIA, TEL. 72 73 57 15'},
#    {'CONSEILLER GENERAL': 'OUEDRAOGO SOULEYMANE, TEL. 78 82 11 67'},
#    {'REPRESENTANTE DES FEMMES': 'OUEDRAOGO HABIBATA, TEL. 72 86 27 56'},
#    {'PRESIDENT': 'OUEDRAOGO ISSA, TEL. 76 66 44 33'},
#    {"SECRETAIRE A L'INFORMATION": 'OUEDRAOGO MOUSSA, TEL. 78 99 13 22'}]},
#  {'Association number': ('2015- 464/matd/sg/dglpap/doasoc', '20 août 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'SANFO FATIMATA, TEL. 76 57 31 25'},
#    {'SECRETAIRE GENERAL': 'ZIO AYOUBA, TEL. 79 00 54 32'},
#    {'VICE-PRESIDENT': 'SAWADOGO ALBERT, TEL. 70 33 62 66'},
#    {'PRESIDENT': 'TONDE ADAMA, TEL. 70 24 68 94'},
#    {"SECRETAIRE A L'INFORMATION": "ET A L'ANIMATION NIGNAN DAOUDA, TEL. 68 16 71 54"},
#    {'TRESORIERE': 'OUEDRAOGO W. HONORINE, TEL. 70 62 57 25'}]},
#  {'Association number': ('2015- 411/matd/sg/dglpap/doasoc', '31 juillet 2015'),
#   'Members': [{"SECRETAIRE ADJOINTE A L'ORGANISATION ET A LA COMMUNICATION": 'NANA ALIMATA, TEL. 60 50 82 78'},
#    {'TRESORIERE ADJOINTE': 'YALPOUGDOU JESICA, TEL. 68 69 67 73'},
#    {'SECRETAIRE ADJOINT': "E A L'ORGANISATION ET A LA COMMUNICATION NANA ALIMATA, TEL. 60 50 82 78"},
#    {"SECRETAIRE A L'ORGANISATION": 'ET A LA COMMUNICATION TAPSOBA ARISTIDE, TEL. 75 44 77 77'},
#    {'SECRETAIRE GENERAL': 'TIENDREBEOGO ARSENE, TEL. 73 55 31 90'},
#    {'VICE-PRESIDENT': 'KABORE HOUSSENI, TEL. 77 44 37 42'},
#    {"SECRETAIRE A L'ORGANISATION ET A LA COMMUNICATION": 'TAPSOBA ARISTIDE, TEL. 75 44 77 77'},
#    {'PRESIDENT': 'E OUEDRAOGO ALIZETA, TEL. 76 06 66 99'},
#    {'CHARGE DE LA QUESTION FEMININE': 'FOFANA ALASSANE, TEL. 64 93 29 98'},
#    {'TRESORIERE': 'SANKARA DJAMINTA, TEL. 72 93 98 20'}]},
#  {'Association number': ('2015- 028/matd/rnrd/gvr-ohg/sg', '19 août 2015'),
#   'Members': [{'SECRETAIRE GENERAL': 'OUEDRAOGO ABDOULAYE,TEL.70 0444 10'},
#    {'PRESIDENT': 'ZOROM BRAHIMA, TEL. 78 48 71 17/70 88 92 72'},
#    {"SECRETAIRE A L'INFORMATION": "ET A L'ORGANISATION SAVADOGO PACODE, TEL. 70 61 85 15"},
#    {'TRESORIERE': 'GENERALE KINDO ROUKIETOU, TEL. 66 69 90 56'}]},
#  {'Association number': ('2015- 429/matdisgidglpapidoasoc', '06 août 2015'),
#   'Members': [{'SECRETAIRE ADJOINT
2015'),
#   'Members': [{'SECRETAIRE ADJOINT': "E A L'INFORMATION OUEDRAOGO ASSETA, RESIDE A KORSIMORO"},
#    {"SECRETAIRE A L'ORGANISATION": 'OUEDRAOGO OUSSENI, RESIDE A KORSIMORO'},
#    {'SECRETAIRE GENERAL': 'OUEDRAOGO RASMANE, TEL. 76 40 72 43'},
#    {'VICE-PRESIDENT': 'OUEDRAOGO HAMIDOU, RESIDE A KORSIMORO'},
#    {'PRESIDENT': 'OUEDRAOGO KARIM, TEL. 7607 46 14/70 55 17 12'},
#    {'TRESORIER GENERAL': 'OUEDRAOGO ISSA, RESIDE A KORSIMORO TRESORIER GENERAL ADJOINT OUEDRAOGO MADI, TEL. 77 16 95 70'},
#    {"SECRETAIRE A L'INFORMATION": 'YAMEOGO DJIBRINE, RESIDE A KORSIMORO'}]},
#  {'Association number': ('2015- 180/matd/rcen/pkad/hc/sg/dase',
#    '20 août 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': 'E A LA TRESORERIE KABORE SALAMATA, TEL. 71 57 74 59'},
#    {'SECRETAIRE GENERAL': 'ZEMBA W. EMMANUEL, TEL. 79 21 62 21 PAGE 22 636 JOURNAL OFFICIEL DU BURKINA FASO N° 37 10 SEPTEMBRE 2015'},
#    {'VICE-PRESIDENT': 'KANAZOE SITA, S/C TEL. 76 40 28 94'},
#    {'PRESIDENT': 'KIETTYETTA PAUL, TEL. 76 40 71 89/76 40 28 94'}]},
#  {'Association number': ('2015- 368/matdsisg/dglpap/doasoc',
#    '09 juillet 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'KONDOMBO AZARIA, TEL. 79 50 93 02'},
#    {'SECRETAIRE ADJOINT': "A L'ORGANISATION ET L'INFORMATION OUEDRAOGO JACQUES, TEL. 79 03 52 41"},
#    {"SECRETAIRE ADJOINT A L'ORGANISATION": "ET L'INFORMATION OUEDRAOGO JACQUES, TEL. 79 03 52 41"},
#    {"SECRETAIRE A L'ORGANISATION": "ET A L'INFORMATION SAWADOGO EMMANUEL, TEL. 79 03 13 94"},
#    {'SECRETAIRE GENERAL': 'BAYALA JANVIER, TEL. 78 50 01 97'},
#    {'VICE-PRESIDENT': 'OUEDRAOGO DAVID, TEL. 76 56 73 71'},
#    {'PRESIDENT': 'KONDOMBO ADAMA,TEL. 76 10 53 03'},
#    {'TRESORIER GENERAL': 'OUEDRAOGO DAOUDA, TEL. 79 68 63 75'},
#    {'TRESORIERE': 'ADJOINTE KONDOMBO AZARIA, TEL. 79 50 93 02'}]},
#  {'Association number': ('2015- 394/matdsisg/dglpap/doasoc',
#    '21 juillet 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'YOUGBARE JUSTINE, TEL. 61 13 01 88'},
#    {"SECRETAIRE A L'ORGANISATION": 'ET A LA COMMUNICATION COMPAORE AIDA, TEL. 68 76 76 13'},
#    {'SECRETAIRE GENERAL': 'SANFO ABDOUL GUELIL, 01 BP 361 OUAGA 01, TEL. 79 02 15 72'},
#    {'VICE-PRESIDENT': 'E NIKIEMA EDWIGE, 09 BP 1143 OUAGA 09, TEL. 66 13 87 85'},
#    {"SECRETAIRE A L'ORGANISATION ET A LA COMMUNICATION": 'COMPAORE AIDA, TEL. 68 76 76 13'},
#    {'PRESIDENT': 'NABYOURE AIME, 01 BP 10000 OUAGA 01, TEL. 78 30 22 22'},
#    {'TRESORIERE': 'ADJOINTE YOUGBARE JUSTINE, TEL. 61 13 01 88'}]},
#  {'Association number': ('2015- 473/matd/sg/dglpap/doasoc', '25 août 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': 'A LA COMMUNICATION ET AUX RELATIONS EXTERIEURES KARAMBIRI BRUNO, TEL. 70 32 72 93'},
#    {"SECRETAIRE A L'ORGANISATION": 'BELEM SEYDOU, TEL. 78 99 80 24'},
#    {'SECRETAIRE GENERAL': 'ZOUGMORE ANTOINE HAMADO, TEL. 70 23 97 35'},
#    {'PRESIDENT': 'POUAHOULABOU P. K. VICTOR, TEL. 70 20 41 25'}]},
#  {'Association number': ('2015- 418/matd/sg/dglpap/doasoc', '31 juillet 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': "A L'INFORMATION YOUGOUBO ABDOULAYE, TEL. 75 54 89 69"},
#    {"SECRETAIRE ADJOINT A L'ORGANISATION": 'OUEDRAOGO HOUSSENI, TEL. 66 26 30 97'},
#    {"SECRETAIRE A L'ORGANISATION": 'DIANE BABALI, TEL. 76 72 36 00'},
#    {'SECRETAIRE GENERAL': 'DALLA MOUMOUNI, TEL. 71 51 50 54'},
#    {'VICE-PRESIDENT': 'BAGUIAN DRAMANE, TEL. 74 86 73 52'},
#    {'PRESIDENT': 'SORGHO YOUNOUSSA.TEL. 71 90 29 42'},
#    {"SECRETAIRE ADJOINT A L'INFORMATION": 'YOUGOUBO ABDOULAYE, TEL. 75 54 89 69'},
#    {"SECRETAIRE A L'INFORMATION": 'NIKIEMA GUILLAUME KISWINDSSIDA, TEL. 74 80 94 09'},
#    {'TRESORIERE': 'GENERALE OUEDRAOGO CHAHADATTE, TEL. 76 45 59 14'}]},
#  {'Association number': ('2015- 448/matd/sg/dglpap/doasoc', '11 août 2015'),
#   'Members': [{'PRESIDENT': 'FONDATEUR: TAMINI SANKUY BIAISE, TEL. 76 61 85 98/ 70 75 39 72'},
#    {"SECRETAIRE A L'INFORMATION": "ET A L'ORGANISATION TORA SEVERIN, TEL. 78 33 90 04"},
#    {'TRESORIERE': 'S ZONOU DINA, TEL. 70 69 14 34'}]},
#  {'Association number': ('2015- 478/matd/sg/dglpap/doasoc', '26 août 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': "E A L'INFORMATION OUEDRAOGO FATIMATA, TEL. 70 68 55 90"},
#    {"SECRETAIRE A L'ORGANISATION": 'KALMOGO PIERRE, 01 BP 3964 OUAGADOUGOU 01, TEL. 70 27 48 85 76 64 40 27'},
#    {'SECRETAIRE GENERAL': 'BARRY IDRISSA, TEL. 78 78 57 20'},
#    {'VICE-PRESIDENT': 'KABORE JEAN ANTOINE, TEL. 70 28 55 12'},
#    {'PRESIDENT': 'TAPSOBA MARIUS, TEL. 70 74 22 55'},
#    {"SECRETAIRE A L'INFORMATION": 'OUEDRAOGO OUSSEINY, TEL. 76 67 16 53'},
#    {'TRESORIERE': 'ZONGO/KAFANDO YVETTE, TEL. 78 67 05 53'}]},
#  {'Association number': ('2015- 413/matd/sg/dglpap/doasoc', '31 juillet 2015'),
#   'Members': [{'SECRETAIRE GENERAL': 
#    {'TRESORIERE': 'GENERALE BARRY/COMPAORE AWA, TEL. 70 57 95 77'}]},
#  {'Association number': ('2015- 474imatd/sg/dglpap/doasoc', '26 août 2015'),
#   'Members': [{"RESPONSABLE ADJOINT A L'INFORMATION": 'BOUGOUMA ISSOUF, TEL. 70 24 42 53 2E'},
#    {'SECRETAIRE GENERAL': 'OUEDRAOGO SALIFOU, TEL. 70 25 11 83 1ER'},
#    {'VICE-PRESIDENT': 'NABI DOMINIQUE, TEL. 70 20 45 04 2EME VICE-'},
#    {'PRESIDENT': 'SANATASSERE, TEL. 70 26 57 65 1ER'},
#    {"RESPONSABLE A L'INFORMATION": 'KABREMADI, TEL. 70 27 12 92 1ER'},
#    {'TRESORIER GENERAL': 'OUEDRAOGO JENA-BAPTISTE, TEL. 78 17 20 60 TRESORIER GENERAL ADJOINT OUEDRAOGO FRANCIS, TEL. 70 25 03 55'}]},
#  {'Association number': ('2015- 426/matdisgidglpap/doasoc', '06 août 2015'),
#   'Members': [{"SECRETAIRE A L'ORGANISATION": '(SO) MASSE MATHIAS, TEL. 76 47 55 23'},
#    {'SECRETAIRE GENERAL': '(SG) PAROU SATURNIN, TEL. 70 06 35 94'},
#    {'PRESIDENT': 'HIEN NANIPOUO, TEL. 70 49 75 01'},
#    {'TRESORIER GENERAL': '(TG) OUEDRAOGO ABDOUL KARIM, TEL. 78 78 48 18'},
#    {"SECRETAIRE A L'INFORMATION": "ET A LA COMMUNICATION (SIC) YODA BRIGITTE, TEL. 71 24 69 70'"},
#    {'TRESORIERE': 'GENERALES ADJOINTE (TGA) KAFANDO P. SONIA, TEL. 70 67 50 67'}]},
#  {'Association number': ('2015- 185/matd/rcen/pkad/hc/sg/dase',
#    '26 août 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'TOE REBECCA, TEL. 70 45 67 97'},
#    {'SECRETAIRE GENERAL': 'KERE PASCAL, TEL. 70 26 14 76'},
#    {'VICE-PRESIDENT': 'DIALLO HAMIDOU OUSMAN, TEL. 70 40 36 44'},
#    {'PRESIDENT': 'GADIAGA DEMBO, TEL. 76 67 70 10'},
#    {'TRESORIERE': 'ZOROME VERONIQUE, TEL. 76 06 13 45'}]},
#  {'Association number': ('2015- 162/matd/rcen/pkad/hc/sg/dase',
#    '31 juillet 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'SAWADOGO AGUERA, TEL. 71 31 01 35'},
#    {'SECRETAIRE ADJOINT': "E L'INFORMATION SINARE MAMOUNTA, TEL. 68 68 50 95"},
#    {"SECRETAIRE A L'ORGANISATION": 'ROUAMBA CELESTINE, TEL. 76 59 13 39'},
#    {'SECRETAIRE GENERAL': 'KABORE NORBERT, TEL. 79 90 28 39'},
#    {'VICE-PRESIDENT': 'NANA BASSIROU, TEL. 78 78 87 06'},
#    {'PRESIDENT': 'E SANKARA MARIAM, TEL. 70 88 27 75'},
#    {"SECRETAIRE A L'INFORMATION": 'GANSORE CATHERINE, TEL. 79 97 52 63'},
#    {'TRESORIERE': 'GENERALE SIMPORE BIBIANE, TEL. 78 07 95,53'}]},
#  {'Association number': ('2015- 218/matds/rhbs/phue/hcbdls/sg/dag',
#    '08 juillet 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': 'SAWADOGO AMADE, SECTEUR 02 BOBO- DIOULASSO, TEL. 76 46 93 93'},
#    {"SECRETAIRE A L'ORGANISATION": 'DERRA SEYDOU, SECTEUR 03 BOBO-DIOULASSO, TEL. 78 27 42 67'},
#    {'SECRETAIRE GENERAL': 'BELEM BABA, TEL. 76 48 08 29'},
#    {'VICE-PRESIDENT': 'EL HADJI ZIDA INOUSSA, SECTEUR 02 BOBO- DIOULASSO, TEL. 70 42 98 46'},
#    {'PRESIDENT': 'EL HADJI YAOGO ISSIAKA, SECTEUR 02 BOBO- DIOULASSO, TEL. 70 24 78 92'},
#    {"SECRETAIRE ADJOINT A L'INFORMATION": 'SOUDRE ABDOULAYE, SECTEUR 02 BOBO-DIOULASSO, TEL. 75 18 26 81'},
#    {"SECRETAIRE A L'INFORMATION": 'ZONGO SOUMAÏLA, SECTEUR 04 BOBO-DIOULASSO, TEL. 76 60 37 16'}]},
#  {'Association number': ('2015- 255/matds/rhbs/phue/hcbdls/sg/dag',
#    '29 juillet 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'TRAORE SITA BEA, TEL. 71 70 17 23'},
#    {'SECRETAIRE ADJOINT': "A L'ORGANISATION KOUYATE KADIATOU, TEL. 70 11 54 79"},
#    {"SECRETAIRE ADJOINT A L'ORGANISATION": 'KOUYATE KADIATOU, TEL. 70 11 54 79'},
#    {"SECRETAIRE A L'ORGANISATION": 'SORE KADI, TEL. 76 41 71 07'},
#    {'SECRETAIRE GENERAL': 'E SANOGO AOUA, TEL. 75 00 35 42'},
#    {'PRESIDENT': 'E KONE MINATA, TEL. 78 23 11 53'},
#    {"SECRETAIRE A L'INFORMATION": 'GAKOU BINTOU,TEL. 78 97 03 25'},
#    {'TRESORIERE': 'GENERALE KONE MAIMOUNA, TEL. 78 09 03 23'}]},
#  {'Association number': ('2015- 034/matds/rnrd/pytg/hc-ohg/sg',
#    '24 juillet 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': "A L'ORGANISATION DEMEA OSSENI, TEL. 76 91 75 62"},
#    {"SECRETAIRE ADJOINT A L'ORGANISATION": 'DEMEA OSSENI, TEL. 76 91 75 62'},
#    {"SECRETAIRE A L'ORGANISATION": 'SANA MOUSSA DE B, TEL. 74 75 52 38'},
#    {'SECRETAIRE GENERAL': 'SANA SALAM, TEL. 78 56 79 21'},
#    {'VICE-PRESIDENT': 'MAIGA SADA, TEL. 74 62 35 87'},
#    {'PRESIDENT': 'SANA ISSA, TEL. 75 00 90 94'},
#    {'SECRETAIRE AUX AFFAIRES CULTURELLES': 'ET SPORTIVES SANA MOUSSA DE M., TEL. 76 61 80 79'},
#    {'TRESORIER GENERAL': 'SANA SALIFOU, TEL. 75 16 47 45 TRESORIER ADJOINT GUIRO ANAS, TEL. 74 95 93 34'},
#    {"SECRETAIRE A L'INFORMATION": 'SANA ZOENABOU DE B., TEL. 76 85 40 93'}]},
#  {'Association number': ('2015 057/matds/rcos/pblk/hc-kdg/sg', '19 mars 2015'),
#   'Members': [{'SECRETAIRE GENERAL': 'YAMEOGO K. ISIDORE, S/CTEL. 71 14 84 67'},
#    {'PRESIDENT': 'YAMEOGO AUGUSTIN, TEL. 71 14 84 67'},
#    {"RESPONSABLE A L'INFORMATION": 'NASSAZENABOU.TEL. 70 27 47 49'},
#    {'TRESORIERE': 'GENERALE SIMPORE ANNE, TEL. 70 80 43 76'}]},
#  {'Association number': ('2015- 085/matds/rcas/pcmo/hc', '14 juillet 2015'),
#   'Members': [{"RESPONSABLE ADJOINT A L'INFORMATION": 'KARAMA BERNARD, TEL. 70 96 15 35'},
#    {'SECRETAIRE GENERAL': 'DIALLO OUSSENI, TEL. 70 74 40 80'},
#    {'VICE-PRESIDENT': 'E BAGUE ALI, TEL. 70 59 24 07'},
#    {'PRESIDENT': 'E: YOIN BESSAMBIE BASILE, TEL. 70 99 16 72'},
#    {"RESPONSABLE A L'INFORMATION": 'OUEDRAOGO SANOUSSA, TEL. 78 00 96 88'},
#    {'TRESORIERE': 'NAON YASSI, TEL. 78 77 95 28'}]},
#  {'Association number': ('2015- 018/matd/rbmh/pbl/hc-brm', '19 août 2015'),
#   'Members': [{'SECRETAIRE GENERAL': 'E NAON KOLE, TEL. 70 52 90 63'},
#    {'VICE-PRESIDENT': 'E BAGUE ALI, TEL. 70 59 24 07'},
#    {'PRESIDENT': 'E: YOIN BESSAMBIE BASILE, TEL. 70 99 16 72'},
#    {"RESPONSABLE A L'INFORMATION": 'ADJOINTE NAON EBOU, TEL. 71 25 57 50'},
#    {'TRESORIERE': 'NAON YASSI, TEL. 78 77 95 28'}]},
#  {'Association number': ('2015- 025/matd/rbmh/pmhn/hc-ddg/sg', '12 août 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': "A L'ORGANISATION TIDGA KALIZETA"},
#    {"SECRETAIRE ADJOINT A L'ORGANISATION": 'TIDGA KALIZETA'},
#    {"SECRETAIRE A L'ORGANISATION": 'SANGARE BOUKARY, TEL. 72 45 32 20 78 72 23 46'},
#    {'SECRETAIRE GENERAL': 'OUEDRAOGO ISMAEL, TEL. 60 04 29 80'},
#    {'VICE-PRESIDENT': 'E BOENA MARIAM, TEL. 60 34 22 32'},
#    {'PRESIDENT': 'OUEDRAOGO AMIDOU, TEL. 70 64 95 41 78 48 95 80'},
#    {"SECRETAIRE ADJOINT A L'INFORMATION": 'ET A LA COMMUNICATION SORE HAMIDOU, TEL. 62 29 51 90'},
#    {'TRESORIER GENERAL': 'ADJOINT BELEM ABOU, TEL. 60 38 73 22'},
#    {"SECRETAIRE A L'INFORMATION": 'ET A LA COMMUNICATION SANKARA BOUREIMA,TEL. 70 85 40 68 68 31 82 72'},
#    {'TRESORIERE': 'GENERALE BADINI KALIZETA, TEL. 71 79 77 42'}]},
#  {'Association number': ('2015- 004imatd/rcnr/pnmt/hcisg', '18 août 2015'),
#   'Members': [{"SECRETAIRE A L'ORGANISATION": 'IMABARKIMBA, BOULSA, SECTEUR N° 3, S/C TEL. 61 59 33 22'},
#    {'SECRETAIRE GENERAL': 'E IMA TENE, BOULSA, SECTEUR N" 3, TEL. 71 13 59 41'},
#    {'VICE-PRESIDENT': 'E ZIDOUEMBA KOUKA VERONIQUE, BOULSA, SECTEUR N° 3, TEL. 72 33 51 84'},
#    {'PRESIDENT': 'E LONFO GANTA, BOULSA, SECTEUR N° 3, TEL. 61 59 33 22'},
#    {"SECRETAIRE A L'INFORMATION": 'ZONGO PENDO, BOULSA, SECTEUR N° 3, TEL. 60 17 78 51'},
#    {'TRESORIERE': 'GENERALE KIENDREBEOGO SIBDOU, BOULSA, SECTEUR N° 3, S/C TEL. 61 59 33 22'}]},
#  {'Association number': ('2015- 018/matds/rpcl/pkwg/hc/sg', '18 août 2015'),
#   'Members': [{'SECRETAIRE ADJOINT': 'TAPSOBA ZAKARIA, TEL. 68 24 43 76'},
#    {'SECRETAIRE GENERAL': 'OUEDRAOGO RASMANE, TEL. 70 52 01 31'},
#    {'VICE-PRESIDENT': 'OUEDRAOGO INOUSSA, TEL. 79 68 29 25'},
#    {'PRESIDENT': 'OUEDRAOGO BOUREIMA, TEL. 78 72 90 24'},
#    {'TRESORIER GENERAL': 'ZORE ABDOULAYE, TEL. 76 25 53 49 TRESORIER ADJOINT KINDA SALIF, TEL. 78 17 54 28'},
#    {"SECRETAIRE A L'INFORMATION": 'OUEDRAOGO SOULEYMANE, TEL. 78 61 45 29'}]},
#  {'Association number': ('2015- 024/matd/rest/pgng/hc', '24 août 2015'),
#   'Members': [{'TRESORIERE ADJOINTE': 'MANO/LANKOANDE DAGOBA, BOGANDE, TEL. 70 80 53 24'},
#    {'SECRETAIRE GENERAL': 'E NAGANDA/LANKOANDE D. FLORENCE, BOGANDE, TEL. 70 64 82 66'},
#    {'VICE-PRESIDENT': 'E YARGA/LANKOANDE TANI, BOGANDE, TEL. 70 64 06 38'},
#    {'PRESIDENT': 'E KOUDOUGOU/LANKOANDE ARDIOUMBOUGA B, BOGANDE, TEL. 70 25 09 32'},
#    {"RESPONSABLE A L'INFORMATION": "ET A L'ORGANISATION DAYAMBA AHANDOU, BOGANDE, TEL. 70 89 84 36"},
#    {'TRESORIERE': 'GAYERI SALAMATOU, BOGANDE, TEL. 78 48 33 66'}]}]

# %%
import json
def load_json(filepath: str) -> json:
    with open(filepath, 'r') as f:
        file = json.load(f)

    return file

# %%
def build_csvs():
    # For Association
    path_tmp_associations = os.path.join("data", "temp", "associations")
    tmp_associations = os.listdir(path_tmp_associations)
    tmp_associations_files_paths = [os.path.join("data", "temp", "associations", file_name) for file_name in os.listdir(path_tmp_associations)]

    associations_list = []

    for tmp_assoc_path in tmp_associations_files_paths:
        curr_tmp_assoc = load_json(tmp_assoc_path)

        associations_list += curr_tmp_assoc
    
    return(associations_list)

# %%
build_csvs()
# Out:
# [{'id': '46c3df9fea0f1ef345742aef2adde148',
#   'declaration number': ['2008- 0006/matd/sg/dglpap/doasoc',
#    '25 janvier 2008'],
#   'details': {'number': '2008- 0006/matd/sg/dglpap/doasoc',
#    'date': '25 janvier 2008',
#    'denomination': 'COLLECTIF DES ASSOCIATIONS DES RESTAURATRICES ET TRANSFORMATRICES DES PRODUITS LOCAUX',
#    'objective': 'Lassociation collectif des associations des restauratrices et transformatrices des produits locaux a pour objectifs dœuvrer à renforcer les capacites institutionnelles et les competences des membres dans les domaines de la communication, de la mobilisation, du plaidoyer de la negociation et la mise en œuvre des activites de developpement creatrices des dyna- miques damelioration de lenvironnement socio-econo- mique, sanitaire et culturelle  renforcer les capacites institutionnelles et les competences des membres dans les domaines de la mobilisation des res- sources et de la creativites stimuler les synergies au niveau local regional national et international par la mise en reseau de partenaires nationaux et internationaux',
#    'abbreviation': 'CARTPL',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'a2e9d24374023d3b4a9e4cebbb0b65c2',
#   'declaration number': ['2008- 007/ma td/sg/dglpap/doasoc',
#    '25 janvier 2008'],
#   'details': {'number': '2008- 007/ma td/sg/dglpap/doasoc',
#    'date': '25 janvier 2008',
#    'denomination': 'ASSOCIATION POUR LA PROMOTION DE LEDUCATION LA FORMATION ET LE DEVELOPPEMENT',
#    'objective': 'Lassociation pour la promotion de leducation, la formation et le developpement a pour objectifs de promouvoir leducation, la formation et la recherche promouvoir lusage des nouvelles technologies de linforma- tion et de la communication rechercher et financer des projets en matiere deducation et de formation parrainer et soutenir materiellement, techniquement toutes initiatives de developpement promouvoir les activites socioculturelles et sportives assurer la protection de lenvironnement et lutter contre le rechauffement climatique etablir des relations dechange et de cooperation avec les organisations de developpement.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '4f4b38d69d29b97c3b3cbdc2331ff8e4',
#   'declaration number': ['2008- 0047/ma td/rhbs/phue/hcbdls/sg/da g',
#    '25 jan- vier 2008'],
#   'details': {'number': '2008- 0047/ma td/rhbs/phue/hcbdls/sg/da g',
#    'date': '25 jan- vier 2008',
#    'denomination': 'ASSOCIATION DES FRERES UNISFLASO',
#    'objective': 'Lassociation association des freres unis-flaso (afu-f) poursuit les objectifs suivants contribuer à lepanouissement de la jeunesse promouvoir leco-citoyennete cultiver la fraternite et la solidarite au sein de lassociation contribuer au developpement socio-eco',
#    'abbreviation': '',
#    'siege': 'YOROKOKO SECTEUR N°3 COMMUNE DE BOBODIOULASSO PROVINCE DU HOUET'}},
#  {'id': '8a8e1ef8fe3e2a9f23daf4dbe7f4af17',
#   'declaration number': ['2008- 006/matd/rcen/pkad/hc/sg/dase',
#    '29 janvier 2008'],
#   'details': {'number': '2008- 006/matd/rcen/pkad/hc/sg/dase',
#    'date': '29 janvier 2008',
#    'denomination': 'LOLO GNOUMA',
#    'objective': 'Lassociation a pour objectifs de page 17 28 fevrier 2008 journal officiel du burkina faso n°09 305 mobiliser les membres et surtout les femmes autour de leurs interêts sociaux et eco',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU SECTEUR N°28'}},
#  {'id': '382ff1c0f9c167d2bf9990483a8e05a2',
#   'declaration number': ['2008- 032/matd/sg/dglpap/doasoc', '30 janvier 2008'],
#   'details': {'number': '2008- 032/matd/sg/dglpap/doasoc',
#    'date': '30 janvier 2008',
#    'denomination': 'ASSOCIATION MONDE DE PARTAGE',
#    'objective': 'Lassociation monde de partage a pour objectif daider les personnes demunies et particulierement les jeunes et les enfants à travers le partage dans lamour, inculquer le sens du partage dans les mœurs des personnes qui, jadis, etait une pratique de cohesion sociales, de paix et de joie',
#    'abbreviation': 'AMPAR',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '83b4f37dbb6ee3f616c9422b006dd928',
#   'declaration number': ['2008- 035/matd/sg/dglpap/doasoc', '30janvier 2008'],
#   'details': {'number': '2008- 035/matd/sg/dglpap/doasoc',
#    'date': '30janvier 2008',
#    'denomination': 'ASSOCIATION CULTURELLE DAGNIVAMBA',
#    'objective': 'Lassociation culturelle dagni-vamba poursuit les objectifs suivants promouvoir le patrimoine culture! et artistique lutter contre lexcision et le vih/srda assurer une formation appropriee de ses membres',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '260248861f345b476139213df685cc9e',
#   'declaration number': ['2008- 037/matd/sg/dglpap/doasoc', '30janvier 2008'],
#   'details': {'number': '2008- 037/matd/sg/dglpap/doasoc',
#    'date': '30janvier 2008',
#    'denomination': 'DEERI',
#    'objective': 'Lassociation deeri poursuit les objectifs suivants: regrouper les femmes et les jeunes filles pour ensemble cul- tiver les vertus de la solidarite  contribuer à lutter contre la pauvrete par la realisation des projets dinterêts commun à tous les membres de lassocia- tion; mener des actions de sensibilisation sur la sante de la repro- duction œuvrer pour la scolarisation des filles et la promotion de lai- phabetisation des femmes contribuer à la lutte contre la desertification et la conserva- tion des sols appuyer les femmes dans le domaine de lagriculture et de lelevage contribuer à la promotion des droits humains et aux valeurs culturelles nationales etablir un partenariat des droits humains et aux valeurs cul- turelles nationales etablir un partenariat avec les autres associations ayant les mêmes objectifs',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '9117548add0df6c56f57f46b25c644a3',
#   'declaration number': ['2008- 0059/matd/rhbs/phue/hcbdls/sg/dag',
#    '31 jan- vier 2008'],
#   'details': {'number': '2008- 0059/matd/rhbs/phue/hcbdls/sg/dag',
#    'date': '31 jan- vier 2008',
#    'denomination': 'ASSOCIATION NUAGE DENFANTS',
#    'objective': 'Lassociation association nuage denfants a pour objectifs suivants mener les activites generatrices de revenus aider les enfants à reintegrer leur foyers ou leurs familles immediates ameliorer les conditions de vie des enfants defavoriser, et les aider dans leur developpement psycho moteur et psycho intel- lectuel travailler en collaboration ou en partenariat avec des indivi- dus, des institutions burkinabes ou etranger ayant les mêmes objectifs sociaux',
#    'abbreviation': '',
#    'siege': 'SECTEUR N°09 COMMUNE DE BOBODIOULASSO PROVINCE DU HOUET'}},
#  {'id': '7b9dee4f38e75944d7b39a9a15302930',
#   'declaration number': ['2008- 04 7/ma td/sg/dglpa p/doasoc',
#    '05 fevrier 2008'],
#   'details': {'number': '2008- 04 7/ma td/sg/dglpa p/doasoc',
#    'date': '05 fevrier 2008',
#    'denomination': 'ASSOCIATION PROSPECTIVES ET DEVELOPPEMENT LOCAL',
#    'objective': 'Lassociation prospectives et developpement local',
#    'abbreviation': 'APDL',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '920649a31ac2ff1b0ab686828be78b0c',
#   'declaration number': ['2008- 017/matd/rcen/pkad/hc/sg/dase',
#    '07 fevrier 2008'],
#   'details': {'number': '2008- 017/matd/rcen/pkad/hc/sg/dase',
#    'date': '07 fevrier 2008',
#    'denomination': 'MUTUELLE BOLO DI GNONGONMA',
#    'objective': 'La mutuelle a pour objectifs de favoriser des rencontres de concertation et dechanges entre les membres de lassociation ainsi quavec des organisation similaires initier des activites generatrices de revenus pour alimenter la caisse de lassociation contribuer à la reussite de petits projets inities par ses mem- bres participer par des activites socio-educatives et culturelles à lamelioration, à la valorisation de lenvironnement du sec- teur.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU SECTEUR N°30'}},
#  {'id': '1f2a621b59511c36d929f3da1c315974',
#   'declaration number': ['2008- 022/matd/rcen/pkad/hc/sg/dase',
#    '07 fevrier 2008'],
#   'details': {'number': '2008- 022/matd/rcen/pkad/hc/sg/dase',
#    'date': '07 fevrier 2008',
#    'denomination': 'ASSOCIATION POUR LE DEVELOPPEMENT SOCIOEEONOMIQUE DU VILLAGE DE NIONGWARBIN',
#    'objective': 'La federation burkinabe des associations pour la promotion des personnes handicapees a pour objectifs de regrouper en son sein toutes les organisations de/et pour per- sonnes handicapee veiller à la bonne marche des associations membres et le ren- forcement de leur capacite à realiser leur propre programme coordonner les activites des associations des personnes han- dicapees et de favoriser lechange dinformations et dexpe- riences tant sur le plan national quinternational; sensibiliser les personnes handicapees afin quelles sinves- tissent dans le travail en vue de leur auto-promotion promouvoir les relations entre les differentes associations au niveau national, regional et international',
#    'abbreviation': 'ADSEVNW',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '1c1f4c2e494e06c182547c8649dfd77f',
#   'declaration number': ['2008- 056/ma td/sg/dgl pa p/doasoc',
#    '15 fevrier 2008'],
#   'details': {'number': '2008- 056/ma td/sg/dgl pa p/doasoc',
#    'date': '15 fevrier 2008',
#    'denomination': 'FEDERATION BURKINABE DES ASSOCIATIONS POUR LA PROMOTION DES PERSONNES HANDICAPEES',
#    'objective': 'La federation burkinabe des associations pour la promotion des personnes handicapees a pour objectifs de regrouper en son sein toutes les organisations de/et pour per- sonnes handicapee veiller à la bonne marche des associations membres et le ren- forcement de leur capacite à realiser leur propre programme coordonner les activites des associations des personnes han- dicapees et de favoriser lechange dinformations et dexpe- riences tant sur le plan national quinternational; sensibiliser les personnes handicapees afin quelles sinves- tissent dans le travail en vue de leur auto-promotion promouvoir les relations entre les differentes associations au niveau national, regional et international',
#    'abbreviation': 'FEBAH',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'c8c91615531dfee8d8ee8cb019336094',
#   'declaration number': ['2008- 094/matd/sg/dglpap/doasoc',
#    '19 fevrirer 2008'],
#   'details': {'number': '2008- 094/matd/sg/dglpap/doasoc',
#    'date': '19 fevrirer 2008',
#    'denomination': '«ASSOCIATION DE CHRISTMONDE DAMOUR DES CROYANTS',
#    'objective': 'Lassociation croyants',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '2d6eb63accb7d2e6e8ba653f490b6453',
#   'declaration number': ['2015- 866/matd/sg/dglpap/doasoc', '26 octobre 2015'],
#   'details': {'number': '2015- 866/matd/sg/dglpap/doasoc',
#    'date': '26 octobre 2015',
#    'denomination': 'DE LASSOCIATION EGLISE EVANGELIQUE PENTECÔTISTE INTERNATIONALE',
#    'objective': 'Lassociation eglise evangelique pentecôtiste internationale a pour objectifs proclamer la parole de dieu dans les locaux ou en plein air contribuer à lamelioration des conditions de vie des croyants et des non croyants contribuer à la promotion de leducation et la sante.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '724856c088dfc76d37d372f954ee4521',
#   'declaration number': ['2015- 865/matd/sg/dglpap/doasoc', '26 octobre 2015'],
#   'details': {'number': '2015- 865/matd/sg/dglpap/doasoc',
#    'date': '26 octobre 2015',
#    'denomination': 'ASSOCIATION ZOULAMDO POUR LE DEVELOPPEMENT',
#    'objective': 'Lassociation zoulamdo pour le developpement a pour objectifs œuvrer à lamelioration de la situation sanitaire et educative des populations des villages du burkina faso renforcer la disponibilite en eau pour les populations des villages du burkina faso lutter contre la desertification et proteger lenvironnement des villages du burkina faso œuvre à la securite alimentaire des populations des villages du burkina faso promouvoir le developpement dequipements et dinfrastructures sociales et economiques renforcer la participation des femmes dans les actions de developpement assurer la protection sociale des couches vulnerables developper un brassage culturel avec les populations dautres villages ou dautres pays renforcer les relations intergenerationnelles.',
#    'abbreviation': 'AZD',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'b34a5733f2618f2fcd76d194c1045366',
#   'declaration number': ['2015- 852/matd/sg/dglpap/doasoc', '26 octobre 2015'],
#   'details': {'number': '2015- 852/matd/sg/dglpap/doasoc',
#    'date': '26 octobre 2015',
#    'denomination': 'ASSOCIATION AFRICAINE DE MANAGEMENT DE PROJET',
#    'objective': 'Lassociation africaine de management de projet a pour objectif principal de creer un cadre de promotion de bonnes pratiques, referentiels et certifications en management de projets en afrique. ses objectifs specifiques sont promouvoir le management de projet dans tous les milieux socio-economiques en afrique par la formation, linformation, la sensibilisation et la certification promouvoir la diffusion des meilleures pratiques en management de projets en afrique par la formation, linformation et la publication promouvoir les certifications et normalisations en management de projet en afrique developper des reseaux et des cadres dechange dexperiences entre professionnels et theoriciens du management de projets en afrique.',
#    'abbreviation': 'APMA',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO PAGE 20 1314 JOURNAL OFFICIEL DU BURKINA FASO N° 50 10 DECEMBRE 2015'}},
#  {'id': 'f5e7958a291b0c782cfd6ec6dfb88797',
#   'declaration number': ['2015- 457/matd/sg/dglpap/doasoc', '14 août 2015'],
#   'details': {'number': '2015- 457/matd/sg/dglpap/doasoc',
#    'date': '14 août 2015',
#    'denomination': 'ASSOCIATION TEELTAABA',
#    'objective': 'Lassociation teel-taaba a pour objectifs identifier les jeunes et les femmes porteurs de projets dactivites aider à trouver des partenaires techniques et financiers appuyer avec du materiel de recuperation obtenu aupres des partenaires du nord accompagner par une formation en entreprenariat, gestion des activites assurer un suivi et evaluation des activites menees contribuer à lautonomisation economique des couches sociales defavorisees contribuer à la reinsertion sociale des enfants de la rue.',
#    'abbreviation': 'ATT',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '3a51bb872622c3769f3c087a182528a0',
#   'declaration number': ['2015- 853/matd/sg/dglpap/doasoc', '26 octobre 2015'],
#   'details': {'number': '2015- 853/matd/sg/dglpap/doasoc',
#    'date': '26 octobre 2015',
#    'denomination': 'DE PASSOCIATION CONSEIL DES JEUNES POUR UNE EDUCATION POLITIQUE CITOYENNE',
#    'objective': 'Lassociation conseil des jeunes pour une education politique citoyenne a pour objectif general de former des jeunes actifs, dynamiques, eclaires sur les questions politiques et citoyennes, capables dinfluencer les decideurs publics en vue dune societe burkinabe plus juste, equitable et democratique. elle a pour objectifs specifiques former des citoyens capables de sengager, de prendre des initiatives, de developper des sentiments dappartenances à leur nation en vue dune participation veritable à a vie politique de la cite promouvoir la culture africaine et de la citoyennete chez les jeunes contribuer à la formation de la jeunesse dans les domaines du civisme et des droits humains impliquer les populations à la base à lelaboration des politiques les concernant.',
#    'abbreviation': 'COJEPC',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '282a989626ad2821c7eec6b92c51d017',
#   'declaration number': ['2015- 1030/matd/sg/dglpap/doasoc',
#    '13 novembre 2015'],
#   'details': {'number': '2015- 1030/matd/sg/dglpap/doasoc',
#    'date': '13 novembre 2015',
#    'denomination': 'DE LASSOCIATION APPUIJEUNESSE DEVELOPPEMENT',
#    'objective': 'Lassociation appui-jeunesse-developpement a pour objectifs page 21 10 decembre 2015 journal officiel du burkina faso n° 50 1315 soutenir letat burkinabe dans latteinte de ses objectifs de developpement promouvoir lengagement des jeunes dans les instances de decisions (associatives, administratives et politiques) participer au developpement economique, social, culturel et sportif du burkina faso developper des initiatives sous formes de projets socio- economique viables contribuer à lemancipation sociale et à la formation civique de la population unir les jeunes animes dun même ideal et creer entre eux des liens dentente et de solidarite sensibiliser les jeunes sur les mauvaises pratiques et fleaux sociaux encourager la synergie des savoirs et des competences de jeunes pour le developpement en vue dun lendemain meilleur.',
#    'abbreviation': 'AJD',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'cd033ada73df48bfa408427f62472904',
#   'declaration number': ['2015- 923imatdis g/dglpa pi do a soc',
#    '03 novembre 2015'],
#   'details': {'number': '2015- 923imatdis g/dglpa pi do a soc',
#    'date': '03 novembre 2015',
#    'denomination': 'DE LASSOCIATION FONDATION CLIMATE SOL',
#    'objective': 'Lassociation fondation climate sol a pour objectifs realiser un monde où tous les humains vivent en paix, contribuant au respect de la dignite humaine et au developpement integral, responsable et durable installer des systemes integres de lenergie, dassainissement et dagriculture pour un meilleur retablissement des cycles de leau, des elements nutritifs et le cycle du carbone pour une economie plus rationnelle et plus renforcee promouvoir lequilibre ecologique et social, leconomie, la civilisation et lenvironnement contribuer à ameliorer lacces à leau potable lhygiene et lassainissement lenergie renouvelable reduire les emissions des gaz à effet de serre pour un environnement sain et durable restaurer la fertilite et la vitalite des sols pour une agriculture plus productive ameliorer le pouvoir economique et la sante des menages par la mise en place dun systeme de gestion des ressources combustibles accompagner les communautes de base, les differentes organisations et couches sociales dans lanalyse de situation, la recherche de solutions, la planification, la mise en œuvre, le suivi et levaluation dactions de developpement contribuer à la sensibilisation et à la formation dune jeunesse eclairee et engagee pour le developpement contribuer à la securisation fonciere pour un accroissement des investissements en milieu rural et pour un developpement durable.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '820fa63eafdfe9a08dcae4b6d5874907',
#   'declaration number': ['2015- 1013/matd/sg/dglpap/doasoc',
#    '13 novembre 2015'],
#   'details': {'number': '2015- 1013/matd/sg/dglpap/doasoc',
#    'date': '13 novembre 2015',
#    'denomination': 'ASSOCIATION WENDLUITAORE',
#    'objective': 'Lassociation wend-lui-taore a pour objectifs promouvoir lentraide entre les membres promouvoir les activites generatrices de revenu des femmes transformer les produits forestiers non ligneux (soumbala, beurre de karite) lutter pour lassainissement de lenvironnement.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '625491f243ddf3c1eda629c2ca299212',
#   'declaration number': ['2015- 848/matd/sg/dglpap/doasoc', '26 octobre 2015'],
#   'details': {'number': '2015- 848/matd/sg/dglpap/doasoc',
#    'date': '26 octobre 2015',
#    'denomination': 'DE LASSOCIATION SOCIETE BURKINABE DETHNOPHARMACOLOGIE ET DETHNOBOTANIQUE',
#    'objective': 'Lassociation societe burkinabe dethnopharmacologie et dethnobotanique a pour objectif de promouvoir lethnopharmacologie et lethnobotanique en realisant et en favorisant des etudes et des recherches sur les plantes medicinales et les produits dorigine naturelle utilisees par la medecine traditionnelle, la conservation des savoirs techniques, scientifiques et culturels de lutilisation des plantes.',
#    'abbreviation': 'SBEE',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '75a8535a0fb4562ae7ded4d540e43dd5',
#   'declaration number': ['2015- 671/matd/sgidglpapidoasoc',
#    '09 septembre 2015'],
#   'details': {'number': '2015- 671/matd/sgidglpapidoasoc',
#    'date': '09 septembre 2015',
#    'denomination': 'ASSOCIATION JEUNESSE SANS ERONTIERE',
#    'objective': ':l association jeunesse sans frontiere a pour objectifs: sensibiliser les jeunes pour le civisme et la citoyennete sensibiliser sur le bien-fonde de leconomie lutter contre la desertification aider à lalphabetisation promouvoir le developpement de lagriculture et de lelevage promouvoir lintegrite sociale pour un mieux-être sensibiliser les jeunes sur les problemes lies à lurbanisation, le chômage et le tabac sensibiliser les jeunes sur les fleaux sociaux et les maladies sexuellement transmissibles telles que le vih/sida lutter contre lexcision et contre les pratiques qui portent atteintes à la securite et à lepanouissement de la femme participer à la vigilance pour un avenir radieux.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '6cbe989a85931d7fd1da51e22913430f',
#   'declaration number': ['2015- 1029/matd/sg/dglpap/doasoc',
#    '13 novembre 2015'],
#   'details': {'number': '2015- 1029/matd/sg/dglpap/doasoc',
#    'date': '13 novembre 2015',
#    'denomination': 'ASSOCIATION POUR LA GESTION DURABLE DE LENVIRONNEMENT',
#    'objective': 'Lassociation pour la gestion durable de lenvironnement a pour objectif de renforcer le cadre juridique et institutionnel de la gestion durable de lenvironnement, lapplication des textes juridiques en matiere denvironnement, la conservation de la diversite biologique, lattenuation et la resilience des communaute locales aux effets des changements climatiques et lintegration de la durabilite dans les actions de developpement.',
#    'abbreviation': 'AGDE',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '926ab8283c8b3a7c5fb4f9913e02b504',
#   'declaration number': ['2015- 731 ima tdis g/dglpa pid oas oc',
#    '10 septembre 2015'],
#   'details': {'number': '2015- 731 ima tdis g/dglpa pid oas oc',
#    'date': '10 septembre 2015',
#    'denomination': 'ASSOCIATION POUR LE SALUT DES PERSONNES HANDICAPEES DE LA VUE DU BURKINA',
#    'objective': 'Lassociation pour le salut des personnes handicapees de la vue du burkina a pour objectifs apporter la parole de dieu aux personnes en situation dhandicap visuel lutter contre lanalphabetisme au sein des personnes handicapees de la vue œuvrer à lepanouissement socio-economique, culturel et spirituel des personnes handicapees de la vue creer un cadre demancipation des personnes handicapees de la vue.',
#    'abbreviation': 'ASHVB',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '9e22b12ff48d967226e4da0d349f40d2',
#   'declaration number': ['2015- 242/matds/rcen/pkad/hc/sg/dase',
#    '24 novembre 2015'],
#   'details': {'number': '2015- 242/matds/rcen/pkad/hc/sg/dase',
#    'date': '24 novembre 2015',
#    'denomination': 'ASSOCIATION D NABONSWEND TI BUUD NOOMA',
#    'objective': 'Lassociation d nabons-wende ti buud nooma poursuit les objectifs suivants promouvoir le developpement socioculturel et economique de bogodogo travailler au renforcement des liens sociaux entre les ressortissants vivants ailleurs et ceux restes sur place servir de porte-voix de la population aupres des institutions, organismes nationaux et internationaux ameliorer les conditions de vie des personnes vulnerables participer aux differentes luttes engagees par les organisations sœurs de la societe civile au plan national ou international.',
#    'abbreviation': 'ADNTBN',
#    'siege': 'BOGODOGO COMMUNE RURALE DE TANGHINDASSOURI PROVINCE DU KADIOGO'}},
#  {'id': '1914afcf1e78405597c06575bbbbaf89',
#   'declaration number': ['2015- 180/matds/sg/dglpap/doasoc', '05 juin 2015'],
#   'details': {'number': '2015- 180/matds/sg/dglpap/doasoc',
#    'date': '05 juin 2015',
#    'denomination': 'SANCTUAIRE DE GLOIRE DE LETERNEL',
#    'objective': 'Lassociation sanctuaire de gloire de letemel a pour objectifs promouvoir levangile de jesus-christ par levangelisation. ledification des eglises et la formation des disciples regrouper, rassembler et reunir au nom de jesus-christ les hommes et les femmes de toute tribu, toute langue, tout peuple et toute nationalite en vue de former une communaute contribuant à ledification de leglise du christ et à lexpression de la verite doctrinale de christ telle quenoncee par la bible qui est la parole de dieu',
#    'abbreviation': 'SGEL',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '032a8e2e05b1f06f48e13de07c8a6465',
#   'declaration number': ['2015- 948/matd/sg/dglpap/doasoc',
#    '04 novembre 2015'],
#   'details': {'number': '2015- 948/matd/sg/dglpap/doasoc',
#    'date': '04 novembre 2015',
#    'denomination': 'CLUB DES ETUDIANTS ET ANCIENS ETUDIANTS DE MAÎTRISE EN SCIENCES DE GESTION',
#    'objective': 'Lassociation club des etudiants et anciens etudiants de maitrise en sciences de gestion a pour objectifs œuvrer pour une meilleure connaissance de la msg travailler à consolider les relations avec les differentes promotions travailler à elever le taux demployabilite des membres du club faciliter la recherche des stages collaborer avec les autres associations et clubs freres afin dassurer la cohesion au sein de luniversite de ouagadougou et ouaga ii',
#    'abbreviation': 'CIUBMSG',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '36d6455d9fc64ba89aa3d6c79914ab18',
#   'declaration number': ['2015- 021/matd/rcos/pzr/hc-spuy', '29 octobre 2015'],
#   'details': {'number': '2015- 021/matd/rcos/pzr/hc-spuy',
#    'date': '29 octobre 2015',
#    'denomination': 'ASSOCIATION SOUGR NOOMA',
#    'objective': '',
#    'abbreviation': 'ASN',
#    'siege': 'SAPOUY PROVINCE DU ZIRO'}},
#  {'id': '13512a477547a2c933a4a1a897b717e5',
#   'declaration number': ['2015- 334/matd/rhbs/phue/hcbdls/sg/dag',
#    '10 octobre 2015'],
#   'details': {'number': '2015- 334/matd/rhbs/phue/hcbdls/sg/dag',
#    'date': '10 octobre 2015',
#    'denomination': 'ASSOCIATION VOISIN SOLIDAIRE DE SAMANDENI',
#    'objective': 'Lassociation voisin solidaire de samandeni (avs-s) poursuit les objectifs suivants contribuer à lamelioration de letat de sante de la population de zone dintervention contribuer à lamelioration de loffre educative dans sa zone dintervention promouvoir le developpement des secteurs agricoles et de la foresterie villageoise promouvoir les activites sportives et culturelles developper lesprit de solidarite et dentraide entre ses membres',
#    'abbreviation': 'AVSS',
#    'siege': 'SAMANDENI COMMUNE DE BAMA PROVINCE DU HOUET'}},
#  {'id': '1940ef7675b08e4d27a1caae4309ceb7',
#   'declaration number': ['2015- 034/matd/rest/pgng/hc', '10 novembre 2015'],
#   'details': {'number': '2015- 034/matd/rest/pgng/hc',
#    'date': '10 novembre 2015',
#    'denomination': 'ASSOCIATION NUADI N YAMA',
#    'objective': 'Lassociation nuadi n yama poursuit les objectifs suivants former les paysans en technique culturale et maraîchere encourager le maraîchage encourager la consommation des produits locaux promouvoir les activites generatrices de revenus dans la perspective de lauto-emploi chez les jeunes et les femmes lier un partenariat avec les autorites administratives et les services techniques dans la perspectives dune synergie daction encourager à utiliser les revenus de lelevage et de lagriculture pour se soigner, salimenter et se vêtir creer un cadre de concertation sur les potentialites existantes et inviter les partenaires à se pencher sur ces potentialites organiser des seances de sensibilisation sur la frequentation des centres de sante, les bonnes pratiques dhygiene, sur lalimentation du nourrisson et du jeune enfant et sur la planification familiale cultiver le patriotisme local avec une forte implication des leaders locaux sensibiliser la population sur le genre sensibiliser la population sur lauto prise en charge cultiver le civisme',
#    'abbreviation': '(ANYA)',
#    'siege': 'BOGANDE DEPARTEMENT DE LA PROVINCE DE LA GNAGNA'}},
#  {'id': 'cba7ae7abc28185d0220db4b9a42519b',
#   'declaration number': ['2015- 335/ma td/riib s/pi1ue/hci3dls/sg/dag',
#    '30 octobre 2015'],
#   'details': {'number': '2015- 335/ma td/riib s/pi1ue/hci3dls/sg/dag',
#    'date': '30 octobre 2015',
#    'denomination': 'ASSOCIATION GNAMDIO POUR LA PROMOTION DE LA CULTURE SENOUFO',
#    'objective': 'Lassociation gnamdio pour la promotion de la culture senoufo poursuit les objectifs suivants mobiliser, organiser et sensibiliser les amis, les sympathisants et tous ceux qui œuvrent pour le developpement de la culture œuvrer à la recherche de financement pour la realisation de ses projets œuvrer au renforcement des rapports de fraternite entre ses membres œuvrer au renforcement de la collaboration et la complementarite avec les autorites dans le cadre du developpement socio-economique et culturel regrouper toutes les personnes qui veulent œuvrer au developpement socio-economique et culture du senoufo',
#    'abbreviation': 'AGPCS',
#    'siege': 'SECTEUR 21 COMMUNE DE BOBODIOULASSO PROVINCE DU HOUET'}},
#  {'id': 'd12120cd3796546ac9a72f77b8477b2f',
#   'declaration number': ['2015- 1036/matds/sg/dglpap/doasoc',
#    '13 novembre 2015'],
#   'details': {'number': '2015- 1036/matds/sg/dglpap/doasoc',
#    'date': '13 novembre 2015',
#    'denomination': 'CLUB MAFI',
#    'objective': 'Lassociation club mafi a pour objectif principal de promouvoir la filiere mafi et dassurer sa visibilite',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'f68aa33198dfd066978422432905cbe7',
#   'declaration number': ['it° 2015- 1008/matd/sg/dglpap/doasoc',
#    '09 novembre 2015'],
#   'details': {'number': 'it° 2015- 1008/matd/sg/dglpap/doasoc',
#    'date': '09 novembre 2015',
#    'denomination': 'MUTUELLE DES TRAVAILLEURS DE LOUIS DREYFUS COMMODITIES BURKINA FASO',
#    'objective': 'Lassociation mutuelle des travailleurs de louis dreyfus commodities burkina faso a pour objectif de contribuer au bien-être humain et social des employes de ldc bf',
#    'abbreviation': 'MUTRA',
#    'siege': 'BOBODIOULASSO PROVINCE DU HOUET'}},
#  {'id': 'ece0d5f890ad604b3e6f9aa725c036ff',
#   'declaration number': ['2015- 419/matd/sg/dglpap/doasoc', '31 juillet 2015'],
#   'details': {'number': '2015- 419/matd/sg/dglpap/doasoc',
#    'date': '31 juillet 2015',
#    'denomination': 'ASSOCIATION NABONSWENDEZEMSTAABA',
#    'objective': 'Lassociation nabonswende-zemstaaba a pour objectifs reunir un certain nombre de personnes autour dun objectif commun, à savoir la preservation de lenvironnement promouvoir toute activite, tout programme et tout projet entrant dans le cadre de la preservation de lenvironnement impliquer toutes les couches sociales des villes et des campagnes dans la lutte pour la preservation de lenvironnement lutter contre les pratiques negatives telles que la coupe abusive du bois, les feux de brousse, la divagation des animaux conferer aux populations un savoir, un savoir-faire et un savoir être, se traduisant par une prise de conscience collective dans la lutte pour la preservation de lenvironnement',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '9f35e4c75efdf6d64c0f7e3a72828883',
#   'declaration number': ['2015- 898/matd/sg/dglpap/doasoc',
#    '03 novembre 2015'],
#   'details': {'number': '2015- 898/matd/sg/dglpap/doasoc',
#    'date': '03 novembre 2015',
#    'denomination': 'ASSOCIATION POUR LA PROMOTION DES TECHNIQUES INDUSTRIELLES',
#    'objective': 'Lassociation pour la promotion des techniques industrielles a pour objectifs trouver des solutions contributives au developpement economique du burkina faso sensibiliser les differents acteurs du secteur industriel à lutter contre la pollution page 27 10 decembre 2015 journal officiel du burkina faso n° 50 1321 renforcer les competences de ses membres assurer la formation de ses membres faire connaître le patrimoine artisanal et industriel de notre pays faciliter la participation effective des jeunes à des competitions de creativite et à des manifestations tant à linterieur quà lexterieur du pays',
#    'abbreviation': 'APTI',
#    'siege': 'OUAGADOUGOU PROVINCE DU XVADIOGO'}},
#  {'id': '78d01334e22efef968e5017b6595fb41',
#   'declaration number': ['2015- 1071/matd/sg/dglpap/doasoc',
#    '20 novembre 2015'],
#   'details': {'number': '2015- 1071/matd/sg/dglpap/doasoc',
#    'date': '20 novembre 2015',
#    'denomination': 'ASSOCIATION DES PARENTS DES VICTIMES DU COUP DETAT',
#    'objective': 'Lassociation des parents des victimes du coup detat a pour objectifs promouvoir la fraternite et la solidarite entre les membres de lassociation veiller à ce que tous les engagements de letat à leur faveur soient suivis et executes promouvoir des activites socio-economiques au profit des familles initier des actions dans le sens de promouvoir le bien-être de ces familles laissees par ces vaillant heros de la liberte et de la democratie soutenir les initiatives de developpement communautaire allant dans le sens de la reduction des inegalites sociales et concourant au renforcement de la solidarite nationale',
#    'abbreviation': 'APVCE',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '36d6455d9fc64ba89aa3d6c79914ab18',
#   'declaration number': ['2015- 021/matd/rcos/pzr/hc-spuy',
#    '18 novembre 2015'],
#   'details': {'number': '2015- 021/matd/rcos/pzr/hc-spuy',
#    'date': '18 novembre 2015',
#    'denomination': 'ASSOCIATION SOUGR NOOMA',
#    'objective': '',
#    'abbreviation': 'ASN',
#    'siege': 'SAPOUY PROVINCE DU ZIRO'}},
#  {'id': '353c9ba88e0085b367726237ba1443a9',
#   'declaration number': ['2015- 792imatd/sg/dglpap/doasoc',
#    '16 septembre 2015'],
#   'details': {'number': '2015- 792imatd/sg/dglpap/doasoc',
#    'date': '16 septembre 2015',
#    'denomination': 'FLANIW DJIGIYA',
#    'objective': 'Lassociation flaniw djigiya a pour objectifs aider les meres denfants jumeaux en difficulte lutter contre la mendicite des meres de jumeaux',
#    'abbreviation': '',
#    'siege': 'BOBODIOULASSO PROVINCE DU HOUET'}},
#  {'id': '06ccc84efb74a1ad471a56bfb819f1c9',
#   'declaration number': ['2015- 022/matd/rpcl/pgnz/hc/cab', '18 août 2015'],
#   'details': {'number': '2015- 022/matd/rpcl/pgnz/hc/cab',
#    'date': '18 août 2015',
#    'denomination': 'ASSOCIATION KOMWOMA DU GANZOURGOU',
#    'objective': 'Lassociation komwoma du ganzourgou en abrege a.k.g a pour objectifs de creer un cadre de concertation entre ses differents membres creer un elan de solidarite entre ses membres œuvrer pour le bien-être de ses membres œuvrer de concert avec les autorites administratives, politiques, coutumieres et religieuses de la province au bien- être de la population perenniser la parente à plaisanterie apporter une contribuer positive au developpement socio- culturel et economique de la province',
#    'abbreviation': 'AKG',
#    'siege': 'ZORGHO COMMUNE DE ZORGHO PROVINCE DU GANZOURGOU'}},
#  {'id': 'f5dc2bc5291c6826b3752a5247bcc034',
#   'declaration number': ['it° 2015- 942/matdisg/dglpap/doasoc',
#    '04 novembre 2015'],
#   'details': {'number': 'it° 2015- 942/matdisg/dglpap/doasoc',
#    'date': '04 novembre 2015',
#    'denomination': 'CENTRE SCOLAIREPAIN POUR LORPHELIN ET LENFANT VULNERABLE',
#    'objective': 'Lassociation centre scolaire-pain pour lorphelin et lenfant vulnerable a pour objectifs mettre en place des infrastructures adaptees au developpement harmonieux des orphelins et enfants vulnerables (oev) favoriser la scolarisation des orphelins et enfants vulnerables assurer le bien-être materiel, psychosocial, sanitaire et spirituel des oev contribuer à la formation et à linsertion socio- professionnelle des oev qui ne sont plus en âge dêtre scolarises contribuer à la promotion socio-economique des veuves, pour la prise en charge des oev mobiliser les ressources financieres, materielles et humaines necessaire à la realisation des activites du centre',
#    'abbreviation': 'CSPOEV',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '63d285e8844d355b6797177aabe9324e',
#   'declaration number': ['2015- 130/matd/rhbs/gbd/sg/be', '04 novembre 2015'],
#   'details': {'number': '2015- 130/matd/rhbs/gbd/sg/be',
#    'date': '04 novembre 2015',
#    'denomination': 'ASSOCIATION POUR LA PROMOTION DU DEVELOPPEMENT ECONOMIQUE ET SOCIAL DE BOBODIOULASSO',
#    'objective': 'Lassociation pour la promotion du developpement economique et social de bobo-dioulasso (apdes/b) a pour objectifs de contribuer au developpement economique et social de la region des hauts-bassins contribuer à la reduction du chômage qui touche une importante tranche de jeunes de la region des hauts-bassins contribuer à leducation des jeunes et des personnes demunies sur les questions de democraties et de participation citoyenne contribuer à la promotion des droits des personnes vulnerables developper la solidarite en direction des personnes fragiles mettre laccent sur le volet ist/sida par la prise en charge effective des pvv1h/sida, les orphelins et les enfants vulnerables',
#    'abbreviation': 'APDESB',
#    'siege': 'BOBODIOULASSO PROVINCE DU HOUET'}},
#  {'id': '9d8003999f8dbc47c0bc6e8d3795a68e',
#   'declaration number': ['2015- 0946/matd/sg/dglpap/doasoc',
#    '04 novembre 2015'],
#   'details': {'number': '2015- 0946/matd/sg/dglpap/doasoc',
#    'date': '04 novembre 2015',
#    'denomination': 'ASSOCIATION KOGLIZANGA POUR LEPANOUISSEMENT ET LE DEVELOPPEMENT DES JEUNES',
#    'objective': 'Lassociation koglizanga pour lepanouissement et le developpement des jeunes a pour objectifs contribuer au developpement harmonieux et durable en luttant contre le chômage des jeunes, contre la corruption et linjustice contribuer à la protection de lenvironnement par les actions de reboisement, salubrite et assainissement participer à promouvoir leducation en particulier les filles susciter et encourager lesprit creatif et auto emploi des jeunes.',
#    'abbreviation': 'AKOPEDJ',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'a6bb055b50450f0118d240c75d8c6d33',
#   'declaration number': ['2015- 0881imatdisgidglpapidoasoc',
#    '26 octobre 2015'],
#   'details': {'number': '2015- 0881imatdisgidglpapidoasoc',
#    'date': '26 octobre 2015',
#    'denomination': 'MISSION INTERNATIONALE EGLISE DE JESUS CHRIST DU BURKINA FASO',
#    'objective': 'Lassociation mission internationale eglise de jesus christ du burkina faso a pour objectifs temoigner en actes et en paroles de lamour de dieu revele en jesus christ pour le salut de tous ceux qui croiront et seront baptises (me 16 16) consolider la foi des fideles par la predication, lenseignement, la formation et la celebration des cultes et fêtes chretiennes soutenir toute action objective en vue daccomplir lunite des chretiens contribuer à ameliorer les conditions de vie des groupes deplacees, refugies, minorites, victimes de catastrophes diverses) participer à leducation des enfants au burkina faso par louverture detablissement scolaire (primaire et secondaires) et de centres de sante et de formation.',
#    'abbreviation': 'MIEJE',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '21d1b730e9ee579bfae40eeac34407d1',
#   'declaration number': ['2015- 0023/matd/rest/gvrt-fgrm/cab',
#    '28 octobre 2015'],
#   'details': {'number': '2015- 0023/matd/rest/gvrt-fgrm/cab',
#    'date': '28 octobre 2015',
#    'denomination': 'ASSOCIATION TODIMA',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'GAYERI PROVINCE DE LA KOMONDJARI'}},
#  {'id': 'dd84cec8caa1add9a6bae8514c212a1a',
#   'declaration number': ['2015- 01056matd/sg/dglpap/doasoc',
#    '17 novembre 2015'],
#   'details': {'number': '2015- 01056matd/sg/dglpap/doasoc',
#    'date': '17 novembre 2015',
#    'denomination': 'ASSOCIATION DES FEMMES AU DEVELOPPEMENT POUR LE BIEN ETRE',
#    'objective': 'Lassociation des femmes au developpement pour le bien etre a pour objectifs generaux servir de centre dinformation, de formation, et deducation sur le vih/sida et les 1st. la tuberculose, le paludisme, le virus ebola pour la population environnante servir de centre de prise en charge communautaire des quatre pandemies majeures promouvoir la sante des populations à tous les niveaux, la solidarite entre les femmes et renforcer le rôle avant-gardiste des femmes en matiere de prevention de vih/sida et dautres infections sexuellement transmissibles, de tuberculose et de paludisme prevoir un centre dorphelinats. ses objectifs specifiques promouvoir la concertation et lechange entre les femmes et autres organisations de femmes dans tous les domaines accroître la sensibilisation et rendre linformation disponible notamment par le moyen de la formation et de la communication pour un changement de comportement renforcer le partenariat et la collaboration avec les structures etatiques officielles de prise en charge des pandemies soutenir toute initiative de lutte contre le vih/sida, la tuberculose, le paludisme, et le virus ebola des lors quelles sont conforme à la politique nationale en la matiere renforcer le partenariat, la collaboration et la concertation avec les associations, ong et obc de developpement et de lutte contre la pandemie au burkina promouvoir les activites generatrices de revenu pour lauto financement des activites de lassociation promouvoir les droits des personnes en situation de vulnerabilite.',
#    'abbreviation': 'AFDBE',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'cacd81a783433aff0dc48d595967080e',
#   'declaration number': ['2015- 0381/matd/sg/dglpap/doasoc',
#    '09 juillet 2015'],
#   'details': {'number': '2015- 0381/matd/sg/dglpap/doasoc',
#    'date': '09 juillet 2015',
#    'denomination': 'ASSOCIATION VIVRE MIEUX AU TROISIEME AGE',
#    'objective': 'Lassociation vivre mieux au troisieme age a pour objectif creer des structures daccueil pour personnes âgees sensibiliser davantage les communautes sur les meilleures conditions pour vivre une vieillesse adaptee assister les personnes âgees à domicile en milieu hospitalier identifier au maximum les personnes âgees en vue dinstaurer un service socio-sanitaire dans leur milieu de vie encourager les jeunes à sinformer davantage sur les meilleures conditions pour vivre mieux au troisieme âge contribuer à la formation des jeunes sur les modes de vie adaptes pour vivre mieux au troisieme âge identifier les structures nationales et internationales qui œuvrent à ameliorer les conditions de vie du troisieme âge en vue dun partenariat assurer un suivi sanitaire aux personnes âgees.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '67b501cd81894103dabd1f5797311c8d',
#   'declaration number': ['2015- 1049imatd/sg/dglpap/doasoc',
#    '13 novembre 2015'],
#   'details': {'number': '2015- 1049imatd/sg/dglpap/doasoc',
#    'date': '13 novembre 2015',
#    'denomination': 'CONFEDERATION GENERALE DU TRAVAIL DU BURKINA',
#    'objective': 'Lassociation zems-taaba des eleveurs et producteurs de produit agricole a pour objectifs etre une structure viable et perenne, capable de conduire avec succes les activites quelle initie dans le cadre de lexecution de ses programmes projets promouvoir lelevage promouvoir lagriculture promouvoir leducation pour tous contribuer à la protection de lenvironnement etre un cadre de concertation et dechange à travers linformation et à la formation, lassistance et le conseil servir de cadre de consultation entre les partenaires au developpement.',
#    'abbreviation': 'CGTB',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO LE SYNDICAT «CONFEDERATION GENERALE DU TRAVAIL DU BURKINA» A POUR BUTS UNIR ET ORGANISER LES TRAVAILLEURS BURKINABE EN VUE DE DEFENDRE LES INTERÊTS MATERIELS ET MORAUX DE SES MEMBRES CONTRE LA BOURGEOISIE ET LIMPERIALISME LUTTER POUR LA SAUVEGARDE ET LELARGISSEMENT DES LIBERTES DEMOCRATIQUES ET SYNDICALES COORDONNER LACTION DES FEDERATIONS SYNDICALES ET SYNDICATS PROFESSIONNELS MEMBRES ET DEVELOPPER UNE SOLIDARITE MILITANTE AVEC DIFFERENTES CATEGORIES DE TRAVAILLEURS LES TRAVAILLEURS RETRAITES LES TRAVAILLEURS DES CAMPAGNES LES TRAVAILLEURS EMIGRES ETC ET LES SANS EMPLOI ŒUVRER AU RENFORCEMENT DU COURANT SYNDICAT REVOLUTIONNAIRE DE LUTTE DE CLASSES LIER SES LUTTES REVENDICATIVES À CELLES DU PROLETARIAT ET DE MASSES LABORIEUSES BURKINABE POUR LA LIBERATION NATIONALE ET SOCIALE SOUTENIR ET POPULARISER LES LUTTES DES AUTRES TRAVAILLEURS EXPLOITES ET OPPRIMES DU MONDE LA COMPOSITION
UAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'a2cc9474c3761c9f47c1200b0ecf8045',
#   'declaration number': ['2015- 0094/matd/sg/dglpap/doasoc',
#    '03 novembre 2015'],
#   'details': {'number': '2015- 0094/matd/sg/dglpap/doasoc',
#    'date': '03 novembre 2015',
#    'denomination': 'ASSOCIATION ZEMSTAABA DES ELEVEURS ET PRODUCTEURS DE PRODUIT AGRICOLE',
#    'objective': 'Lassociation zems-taaba des eleveurs et producteurs de produit agricole a pour objectifs etre une structure viable et perenne, capable de conduire avec succes les activites quelle initie dans le cadre de lexecution de ses programmes projets promouvoir lelevage promouvoir lagriculture promouvoir leducation pour tous contribuer à la protection de lenvironnement etre un cadre de concertation et dechange à travers linformation et à la formation, lassistance et le conseil servir de cadre de consultation entre les partenaires au developpement.',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': 'b90e35cf986b1340414cdae0a195cf68',
#   'declaration number': ['2015- 0869/matd/sg/dglpap/doasoc',
#    '26 octobre 2015'],
#   'details': {'number': '2015- 0869/matd/sg/dglpap/doasoc',
#    'date': '26 octobre 2015',
#    'denomination': 'ASSOCIATION DES JEUNES MUSULMANS POUR LUNITE ET LA PROMOTION SOCIALE',
# ...
#    'siege': 'SOCIAL SECTEUR 24 COMMUNE DE BOBODIOULASSO'}},
#  {'id': '191636c272d1a6644754f2814203cc8f',
#   'declaration number': ['2018-00461701', '26 septembre 2018'],
#   'details': {'number': '2018-00461701',
#    'date': '26 septembre 2018',
#    'denomination': 'HEALTH ASSISTANCE AND LIFE FOR AIL',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'ce09d25652e3cb8d1c427824dbcdb91c',
#   'declaration number': ['2018- 0037/pblg', '28 septembre 2018'],
#   'details': {'number': '2018- 0037/pblg',
#    'date': '28 septembre 2018',
#    'denomination': 'ASSOCIATION DES RESSORTISSANTS DE GNANGDIN',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'SOCIAL GNANGDIN DEPARTEMENT DE BITTOU'}},
#  {'id': 'a71fbce58547327cb13aa0caa91cc167',
#   'declaration number': ['2018-00459001', '26 septembre 2018'],
#   'details': {'number': '2018-00459001',
#    'date': '26 septembre 2018',
#    'denomination': 'CITOYEN ENGAGE',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '104f56138ba5bad6ed7867012a88b288',
#   'declaration number': ['2018- 0040/pkrt', '08 octobre 2018'],
#   'details': {'number': '2018- 0040/pkrt',
#    'date': '08 octobre 2018',
#    'denomination': 'ASSOCIATION PALINGWENDE DE POUYTENGA',
#    'objective': '',
#    'abbreviation': 'APW',
#    'siege': ''}},
#  {'id': 'd6da2123864e4952baedf8200080c811',
#   'declaration number': ['2018- 00339601', '08 mai 2018'],
#   'details': {'number': '2018- 00339601',
#    'date': '08 mai 2018',
#    'denomination': 'ASSOCIATION JEUNESSE SOLIDAIRE POUR LE DEVELOPPEMENT VERITABLE',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'b2e8d87154625944ae4ac6bda8ae7e21',
#   'declaration number': ['2018- 00448901', '13 août 2018'],
#   'details': {'number': '2018- 00448901',
#    'date': '13 août 2018',
#    'denomination': 'ASSOCIATION YISAN POUR LA PROMOTION DES DROITS DES PERSONNES VIVANT AVEC UN HANDICAP',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'e33cd85041b5016289acbe11841876eb',
#   'declaration number': ['2018- 268/matd/rcen/pkad/hc/sg/sagj',
#    '12 octobre 2018'],
#   'details': {'number': '2018- 268/matd/rcen/pkad/hc/sg/sagj',
#    'date': '12 octobre 2018',
#    'denomination': 'AMICALE DES ANCIENS ELEVES DE TAMPOUY POUR LE DEVELOPPEMENT',
#    'objective': 'Amicale des anciens eleves de tampouy pour le developpement (a.a.e.t.d) poursuit les objectifs suivants promouvoir lexcellence au sein de letablissement organiser des cours de vacances au profit des eleves promouvoir la fraternite entre les jeunes du village promouvoir le civisme et lecocitoyennete promouvoir le developpement local cultiver la solidarite entre les membres',
#    'abbreviation': '',
#    'siege': 'VILLAGE DE TAMPOUYCOMMUNE RURALE DE KOMSILGA PROVINCE DU KADIOGO'}},
#  {'id': '0569cdc4b3fe12ecd80404048aa74e35',
#   'declaration number': ['2018- 051/pcmo', '02 octobre 2018'],
#   'details': {'number': '2018- 051/pcmo',
#    'date': '02 octobre 2018',
#    'denomination': 'ASSOCIATION PANISSE',
#    'objective': '',
#    'abbreviation': 'ÊTRE ENSEMBLE EST BIEN',
#    'siege': ''}},
#  {'id': '23e31113012dcb504aba14fe6e2e2254',
#   'declaration number': ['2018-00458701', '26 septembre 2018'],
#   'details': {'number': '2018-00458701',
#    'date': '26 septembre 2018',
#    'denomination': 'SOLIDARITE DES AVEUGLES ET MALVOYANTS DU BURKINA',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'WARMINISAPONE ADRESSE TEL 58 41 50 09'}},
#  {'id': 'c7482345d21c5af6949e64e16f13271d',
#   'declaration number': ['2018- 0046/pytg', '27 septembre 2018'],
#   'details': {'number': '2018- 0046/pytg',
#    'date': '27 septembre 2018',
#    'denomination': '',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '106d846fdd41a9e544709478304b6c65',
#   'declaration number': ['2018- 261/ma td/rcen/pkad/hc/sg/sa gj',
#    '09 octobre 2018'],
#   'details': {'number': '2018- 261/ma td/rcen/pkad/hc/sg/sa gj',
#    'date': '09 octobre 2018',
#    'denomination': 'ASSOCIATION BOUDNOMA DES RESSORTISSANTS DU GANZOURGOU',
#    'objective': 'Lassociation boud-noma des ressortissants du ganzourgou, (a.b.n.r.g) poursuit les objectifs suivants developper lesprit de solidarite et de cohesion sociale autour dun cadre de concertation entre les membres contribuer à lutter contre les fleaux tels que le vih/sida, les formes dhepatites, les cancers du sein et du col de luterus ainsi que la pratique de lexcision renforcer les liens avec les associations sœurs promouvoir la collaboration avec les autorites administratives et locales contribuer à instaurer et à consolider les liens fraternels et de solidarite entre les ressortissants de ganzourgou residant à ouagadougou favoriser la concertation entre les membres dans le but de developper et promouvoir la lutte contre lexclusion sociale, le sous-developpement et la pauvrete promouvoir la solidarite et lentraide entre les membres de lassociation et les partenaires socioeconomiques et politiques dans le souci de relancer le developpement local du ganzourgou promouvoir la mecanisation agricole promouvoir le reboisement et lutter contre la desertification developper et maintenir un partenariat dynamique entre les associations dune part et dautres part entre les ong, les projets ou toutes autres personnes morales ou physiques',
#    'abbreviation': 'ABNRG',
#    'siege': 'SECTEUR 53 ARRONDISSEMENT 12 OUAGADOUGOU PROVINCE DU KADIOGO'}},
#  {'id': '23224da7854e59f38a7f5aa3f6d2b159',
#   'declaration number': ['2018- 0049/pytg', '27 septembre 2018'],
#   'details': {'number': '2018- 0049/pytg',
#    'date': '27 septembre 2018',
#    'denomination': '',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'c5150940422ecdb4ab5b9ff20b6079d8',
#   'declaration number': ['2018-079', '05 octobre 2018'],
#   'details': {'number': '2018-079',
#    'date': '05 octobre 2018',
#    'denomination': 'ASSOCIATION NAZOU TANGANZOU BIGA',
#    'objective': '',
#    'abbreviation': 'NTB',
#    'siege': ''}},
#  {'id': 'fdf4a9479260366bfefff2fb3133e1b3',
#   'declaration number': ['2018- 0037/pkrt', '14 septembre 2018'],
#   'details': {'number': '2018- 0037/pkrt',
#    'date': '14 septembre 2018',
#    'denomination': 'ASSOCIATION POUR LE DEVELOPPEMENT LOCAL DANS LE KOURITTENGA',
#    'objective': '',
#    'abbreviation': 'ADLK',
#    'siege': ''}},
#  {'id': '1478a7c47a425accde2ec0cbb57f684b',
#   'declaration number': ['2018- 0036/pblg', '21 août 2018'],
#   'details': {'number': '2018- 0036/pblg',
#    'date': '21 août 2018',
#    'denomination': 'ASSOCIATION POUR LE BIEN ETRE DE LA FAMILLE DE NIAOGHO',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '6d5f42dedcc56b401007009b7976ea25',
#   'declaration number': ['2018-00464501', '08 octobre 2018'],
#   'details': {'number': '2018-00464501',
#    'date': '08 octobre 2018',
#    'denomination': 'EGLISE EVANGELIQUE PRESBYTERIENNE DU BURKINA FASO',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '20a4ea3daef9095a51888748b72a9c09',
#   'declaration number': ['2018- 00373801', '17 octobre 2018'],
#   'details': {'number': '2018- 00373801',
#    'date': '17 octobre 2018',
#    'denomination': 'SOS SAHEL INTERNATIONAL BURKINA FASO',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU ADRESSE TEL 70 78 27 17 DOMAINE DINTERVENTION ENVIRONNEMENT ET DEVELOPPEMENT DURABLE'}},
#  {'id': '4f7e8619cbfcc31155d749e7c62e1488',
#   'declaration number': ['2018- 113/ma td/rcnr/psnm/hc', '05 septembre 2018'],
#   'details': {'number': '2018- 113/ma td/rcnr/psnm/hc',
#    'date': '05 septembre 2018',
#    'denomination': 'ASSOCIATION SONGTAABA DES JEUNES POUR LE DEVELOPPEMENT DE KORSIMORO',
#    'objective': '',
#    'abbreviation': 'ASJDK',
#    'siege': ''}},
#  {'id': 'eb1f98d4ec9b4eee8c3252b7773e9326',
#   'declaration number': ['2018- 00381701', '10 octobre 2018'],
#   'details': {'number': '2018- 00381701',
#    'date': '10 octobre 2018',
#    'denomination': 'ASSOCIATION WENDSONGDO',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '26847885d9d494b65a1c88187b6006b0',
#   'declaration number': ['2018- 00459801', '26 septembre 2018'],
#   'details': {'number': '2018- 00459801',
#    'date': '26 septembre 2018',
#    'denomination': 'AMICALE DES FEMMES DE LASSEMBLEE NATIONALE PAGE 49 22 NOVEMBRE 2018 JOURNAL OFFICIEL DU BURKINA FASO N°47 3245',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '367f232e67af9d6da83fc2458ac395a1',
#   'declaration number': ['2018-038 r/vrd', '30 août 2018'],
#   'details': {'number': '2018-038 r/vrd',
#    'date': '30 août 2018',
#    'denomination': 'ASSOCIATION ENSEMBLE SAUVEGARDONS LA DIGNITE AFRICAINE',
#    'objective': '',
#    'abbreviation': 'AESDA',
#    'siege': ''}},
#  {'id': '8c6ce8402e1ba811a20494527dcf8555',
#   'declaration number': ['2018-0438901', '11 juillet 2018'],
#   'details': {'number': '2018-0438901',
#    'date': '11 juillet 2018',
#    'denomination': 'ASSOCIATION TOGONI',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'OUAGADOUGOU'}},
#  {'id': '8342130f36341ccb431e2aed4ca0f09d',
#   'declaration number': ['2018-030 pblg', '06 septembre 2018'],
#   'details': {'number': '2018-030 pblg',
#    'date': '06 septembre 2018',
#    'denomination': 'ASSOCIATION SUGRNOOMA DES JEUNES DE GOUDAYERIE',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'SOCIAL BAGRE'}},
#  {'id': 'a6f9ca1bf68b8b75b83c8e573e916b46',
#   'declaration number': ['2018-0325301', '17 mai 2018'],
#   'details': {'number': '2018-0325301',
#    'date': '17 mai 2018',
#    'denomination': 'ASSOCIATION DES JEUNES ENTREPRENEURS AU BURKINA EN AGRI BUSINESS',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '4e230bbf1132e160b3712101ae7cb39d',
#   'declaration number': ['2018-007 pgrm', '07 août 2018'],
#   'details': {'number': '2018-007 pgrm',
#    'date': '07 août 2018',
#    'denomination': 'ASSOCIATION DES COMMERÇANTS DE DIABO',
#    'objective': '',
#    'abbreviation': '(ASC)',
#    'siege': ''}},
#  {'id': 'f2b004d26df12f3961d8631a5a27c7e7',
#   'declaration number': ['2018-0382101', '04 octobre 2018'],
#   'details': {'number': '2018-0382101',
#    'date': '04 octobre 2018',
#    'denomination': 'ASSOCIATION NABONSWENDE POUR LA SOLIDARITE',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'SOCIAL OUAGADOUGOU ADRESSE TEL 70 42 14 92'}},
#  {'id': '3aa375a611f38e0bac4462c7b017ec5c',
#   'declaration number': ['2018-0375701', '26 septembre 2018'],
#   'details': {'number': '2018-0375701',
#    'date': '26 septembre 2018',
#    'denomination': 'ASSOCIATION NOURRIR SANS DETRUIRE',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'SOCIAL OUAGADOUGOU ADRESSE 71 04 00 05'}},
#  {'id': 'cb453cf1777cb4c356559a6c47f0b787',
#   'declaration number': ['2018-0456101', '26 septembre 2018'],
#   'details': {'number': '2018-0456101',
#    'date': '26 septembre 2018',
#    'denomination': 'ASSOCIATION PROFESSIONNELLE DES SOCIETES COTONNIERES DU BURKINA',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'd6c52f2fb712179a931bd691faaff1e3',
#   'declaration number': ['2018-0378601', '04 octobre 2018'],
#   'details': {'number': '2018-0378601',
#    'date': '04 octobre 2018',
#    'denomination': 'ASSOCIATION DES OUVRIERS ET ELEVES DIPLÔMES DES CENTRES DE FORMATION PROFESSIONNELLES',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '496d360499e3d6091070b833a87aff67',
#   'declaration number': ['2018-0369701', '07 août 2018'],
#   'details': {'number': '2018-0369701',
#    'date': '07 août 2018',
#    'denomination': 'ACTION POUR LA PROMOTION DE LENTREPRENEURIAT ET DES SYSTEMES DIRRIGATION',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'a1202cd7e9c2f44501b58e0ea2433a01',
#   'declaration number': ['2018-0024 pnmt', '11 octobre 2018'],
#   'details': {'number': '2018-0024 pnmt',
#    'date': '11 octobre 2018',
#    'denomination': 'ASSOCIATION DES FEMMES WENDPANGA DE DARBILIN',
#    'objective': '',
#    'abbreviation': '',
#    'siege': 'SOCIAL DARBILIN DEPARTEMENT DE DARGO ADRESSE 70 94 42 47'}},
#  {'id': '87f20147d6cce8aa4199a038b8e5956e',
#   'declaration number': ['2018-026 pblg', '24 août 2018'],
#   'details': {'number': '2018-026 pblg',
#    'date': '24 août 2018',
#    'denomination': 'ASSOCIATION KOMALE DE BAGRE',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '986f6cb23aa756668961a726c6ae0de3',
#   'declaration number': ['2018-008 pgrm', '12 septembre 2018'],
#   'details': {'number': '2018-008 pgrm',
#    'date': '12 septembre 2018',
#    'denomination': 'ASSOCIATION BEOG NEERE DE TIONGO',
#    'objective': '',
#    'abbreviation': '(ABNT)',
#    'siege': ''}},
#  {'id': '0dbb9b1cc5ca8937ca29b48eac613711',
#   'declaration number': ['2018-00172 matd/rhbs/phue', '10 août 2018'],
#   'details': {'number': '2018-00172 matd/rhbs/phue',
#    'date': '10 août 2018',
#    'denomination': 'ASSOCIATION SANYA POUR LA PROTECTION DE LENVIRONNEMENT ET POUR LE DEVELOPPEMENT',
#    'objective': '',
#    'abbreviation': 'ASPED',
#    'siege': ''}},
#  {'id': 'f9c20f939c3538627b4c5aaaa27b16a8',
#   'declaration number': ['2018-374401', '26 septembre 2018'],
#   'details': {'number': '2018-374401',
#    'date': '26 septembre 2018',
#    'denomination': 'MOUVEMENT BURKINABE POUR LEVEIL CITOYEN',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'b970e0a99a298c9b133d9fdc2ea3948d',
#   'declaration number': ['2018-0368901', '26 septembre 2018'],
#   'details': {'number': '2018-0368901',
#    'date': '26 septembre 2018',
#    'denomination': 'ASSOCIATION DES VIDANGEURS DU FASO',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '8c212bce02688e0eaf986c92c4616a4c',
#   'declaration number': ['2018-0391701', '24 octobre 2018'],
#   'details': {'number': '2018-0391701',
#    'date': '24 octobre 2018',
#    'denomination': 'ASSOCIATION WEND LA NAAM',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '28efc1a113643849abce6fae19123b9e',
#   'declaration number': ['2018-0470301', '24 octobre 2018'],
#   'details': {'number': '2018-0470301',
#    'date': '24 octobre 2018',
#    'denomination': 'SYNDICAT NATIONAL DES JEUNES COMMERÇANTS ET TRANSPORTEURS',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '65e915e47ef2f0a19b4c1f45396ddb80',
#   'declaration number': ['2019-001/pgng', '20 fevrier 2019'],
#   'details': {'number': '2019-001/pgng',
#    'date': '20 fevrier 2019',
#    'denomination': 'ASSOCIATION DES ANIMATEURS POUR LE DEVELOPPEMENT AGROPASTORAL ET LA PROMOTION DE LHYGIENE ET DE LASSAINISSEMENT DANS LA GNAGNA',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '22faa85262298558115acf6e639bd9d3',
#   'declaration number': ['2019-00177/pytg', '11 mars 2019'],
#   'details': {'number': '2019-00177/pytg',
#    'date': '11 mars 2019',
#    'denomination': '',
#    'objective': '',
#    'abbreviation': 'PROVINCE DU YATENGA',
#    'siege': ''}},
#  {'id': 'cd8a63b282c43f642876205108eff80c',
#   'declaration number': ['2019-0 045/pbzg', '18 fevrier 2019'],
#   'details': {'number': '2019-0 045/pbzg',
#    'date': '18 fevrier 2019',
#    'denomination': 'ASSOCIATION DES JEUNES MECANICIENS DE KOMBISSIRI',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '96788e97d0ae1bb0daa1463ea98e9bc4',
#   'declaration number': ['2019- 00514701', '28 fevrier 2019'],
#   'details': {'number': '2019- 00514701',
#    'date': '28 fevrier 2019',
#    'denomination': '',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': '221946c5902353d29dec3facbe709f47',
#   'declaration number': ['2019-1072', '14 mars 2019'],
#   'details': {'number': '2019-1072',
#    'date': '14 mars 2019',
#    'denomination': '',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'ae33c85135bada77499e8a4a7b06c0ae',
#   'declaration number': ['2019- 152', '28 fevrier 2019'],
#   'details': {'number': '2019- 152',
#    'date': '28 fevrier 2019',
#    'denomination': '',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}},
#  {'id': 'ea905e497c428c594781e76a50e63d43',
#   'declaration number': ['2017- 0044701', '09 janvier 2017'],
#   'details': {'number': '2017- 0044701',
#    'date': '09 janvier 2017',
#    'denomination': '',
#    'objective': '',
#    'abbreviation': '',
#    'siege': ''}}]

# %%
the_file_name = "file_llflg.87648643_20210211_01.txt"
the_file_path = os.path.join("data", "journaux", the_file_name)

# %%
the_file_content = read_file(file_path=the_file_path)
print("Done.")
# Out:
# Done.

# %%
the_file_content = clean_text(the_file_content)
the_file_content
# Out:
# 'PAGE 1 SOIXANTIÈME ANNEE 11 FEVRIER 2021 SPECIAL №05 Journal 1)1 BURKINA FASO Paraissant le jeudi de chaque semaine ABONNEMENTS BURKINA FASO ET AFRIQUE Toute voie 6 mois 1 an 19 500 39 000 AUTRES PAYS Voie aérienne exclusivement Zone Afrique Ouest 100 000 Frs Zone Afrique Nord, Centrale, Australe 150 000 Frs Zone Amérique, Asie 300 000 Frs Zone Europe 300 000 Frs Frais d’expédition en sus Vente de numéro Année courante 750 Année courante spéciale 1000 Année antérieure 900 Année antérieure spéciale 1200 ABONNEMENTS ET INSERTIONS les abonnements et insertions seront adressés au Secrétariat Général du Gouvernement et du Conseil des Ministres 01 BP. 3924 OUAGADOUGOU TEL. 25-32-63-61 25 32-60-19 25 32 60 20/25 32 41 91 Læs lettres demandant réponse devront être accompagnées d’un timbre pour 1 affranchissement. ISSN 07966-5206 Les abonnements et les annonces sont payables d\'avance ANNONCES ET AVIS Association a but non lucratif et avis autre que de constitution de sociétés commerciales 25 000 F CFA Avis de constitution de sociétés commerciales 100 000 F CFA Les annonces devront parvenir au plus tard le jeudi précédant la date de parution du “JO”. EXTRAIT DES MINUTES DU GREFFE DU CONSEIL CONSTITIONNEL x i<> ШЗК SOMMAIRE Décision n°2020-001/CC/EC du 24 octobre 2020 sur la requête de monsieur le Président du Faso aux fins de constater l’impossibilité de réaliser ou d’achever les opérations d’enrôlement des électeurs sur partie du territoire national, en vue des élections couplées du 22 novembre 2020. 5 Décision n°2020-002/CC/EC du 13 décembre 2020 sur requête en date du 10 décembre 2020 de monsieur le Président du Faso aux fins de constater la force majeure entrainant l’impossibilité d’organiser les élections couplées du 22 novembre 2020 sur une partie du territoire national. 7 Décision n°2020-001/CC/EPF du 22 octobre 2020 sur la requête de monsieur BOGNINI Yibouli Lucien aux fins de validation de sa candidature et de son inscription sur la liste définitive des candidats à l’élection du Président du Faso du 22 novembre 2020. 9 Décision n°2020-002/CC/EPF du 22 octobre 2020 sur la requête de monsieur KABORE Boukary en date du 16 octobre 2020 aux fins de validation de sa candidature et de son inscription sur la liste définitive des candidats à l’élection du Président du Faso du 22 novembre 2020. 10 Décision n°2020-003/CC/EPF du 22 octobre 2020 portant sur le recours de monsieur SAWADOGO Issa contre l’invalidation de sa candidature à l’élection du Président du Faso du 22 novembre 2020. 11 Décision n°2020-004/CC/EPF du 22 octobre 2020 portant sur le recours de madame KIELEM/COULIDIATI Justine aux fins de validation de sa candidature à l’élection du Président du Faso du 22 novembre 2020. 12 Décision n°2020-005/CC/EPF du 22 octobre 2020 sur la requête de monsieur SANFO Abdounasira en date du 16 octobre 2020 aux fins de validation de sa candidature et de son inscription sur la liste définitive des candidatures à l’élection du Président du Faso du 22 novembre 2020. 13 Décision n°2020-007/CC/EPF du 22 octobre 2020 sur la requête de monsieur YAMEOGO Salomon Justin en contestation de l’invalidation de sa candidature à l’élection du Président du Faso du 22 novembre 2020. 14 Décision n°2020-008/CC/EPF du 22 octobre 2020 sur le recours en date du 15 octobre 2020 de madame ZON Korotimi Rachya Joséphine Maria Goretti, en inéligibilité de monsieur ZIDA Yacouba Issac et en validation de sa candidature PAGE 2 2 JOURNAL OFFICIEL DU BURKINA FASO SPECIAL №05 11 février 2021 ainsi que celle de monsieur KABORE Boukary, à l’élection du Président du Faso du 22 novembre 2020. 15 Décision n°2020-009/CC/EPF du 22 octobre 2020 portant arrêt et publication de la liste définitive des candidats à l’élection du Président du Faso du 22 novembre 2020. 17 Décision n°2020-010CC/EPF du 24 octobre 2020 portant rectification d’erreur matérielle sur la décision n°2020-009/CC/EPF portant arrêt et publication de la liste définitive des candidats à l’élection du Président du Fas ...

# %%
def extract_declaration_numbers_and_dates(txt):
    results = []
    print("remove é")
    txt = txt.lower().replace("é", "e")
    declaration = "declaration"
    declaration = "\s?".join(declaration)
    declaration += "\s?d?\s?'?"
    declaration += "\s?".join("association")
    # Define the pattern to match the declaration numbers
    print("Creating pattern")
    pattern = re.compile(r"\s?.*?" + declaration + "\s?(.*?du.*?\d{4})")
    # Find all matches of the pattern in the text
    print("pattern.findall(txt)")
    declaration_numbers = pattern.findall(txt)
    # Remove 'n°'
    print("declaration_numbers_dates")
    declaration_numbers_dates = [dc.removeprefix("n°").removeprefix(" n").removeprefix('n"').split("du") for dc in declaration_numbers]
    
    print("for dn_dt in declaration_numbers_dates")
    for dn_dt in declaration_numbers_dates:
        try:
            new_dn_dt = dn_dt[0].strip(), dn_dt[1].strip() if len(dn_dt) == 2 else dn_dt[0].strip()
            results.append(new_dn_dt)
        except:
            pass
    print("END for dn_dt in declaration_numbers_dates")
    

    return results

# %%
extract_declaration_numbers_and_dates(txt=the_file_content)
